# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کنکلی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این تمرین قصد داریم پیش‌بینی کنیم آیا کاربران بلیط خود را کنسل می‌کنند یا نه. به ازای هر کنسلی، مستربلیط باید به شرکت مسافربری جریمه پرداخت کند! پس بلیط‌های    کنسلی به معنی تحمیل هزینه به شرکت است. از این رو تشخیص دادن بلیط‌هایی که احتمال کنسلی آنان وجود دارد، به مدیریت ریسک شرکت کمک بزرگی می‌کند.
#     <br>
#     حال از داده‌هایی که در اختیارتان قرار گرفته است استفاده کنید و مدلی آموزش دهید که کنسل شدن یا نشدن سفر را تشخیص دهد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np
# Out:
# /home/amin/Desktop/Jump Machine Learning/qenv/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه داده آموزشی شامل ۱۰۱۰۱۷ سطر است که در جدول زیر، توضیحات هر ستون آمده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |Created|زمان ثبت بلیط|
# |CancelTime|زمانی که مسافر بلیط را کنسل کرده است|
# |DepartureTime|زمان حرکت|
# |BillID|شناسه خرید|
# |TicketID|شناسه بلیط|
# |ReserveStatus|وضعیت پرداخت مشتری|
# |UserID|شناسه کاربری|
# |Male|آیا بلیط متعلق به زن است یا مرد|
# |Price|قیمت بلیط بدون تخفیف|
# |CouponDiscount|تخفیفی که شخص روی بلیط اعمال کرده است|
# |From|مبدا سفر|
# |To|مقصد سفر|
# |Domestic|آیا سفر، داخلی است یا خارجی|
# |VehicleType|جزئیات وسیله نقلیه را مشخص می‌کند|
# |VehicleClass|آیا وسیله نقلیه، فرست‌کلس است یا نه|
# |Vehicle|نوع وسیله نقلیه|
# |HashPassportNumber_p|هش‌شده شماره پاسپورت|
# |HashEmail|هش‌شده ایمیل|
# |BuyerMobile|هش‌شده شماره موبایل|
# |NationalCode|هش‌شده شماره‌ملی|
# |TripReason|دلیل سفر|
# |Cancel|آیا بلیط کنسل شده‌است یا نه|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     مجموعه داده آزمایش نیز مانند مجموعه آموزش است با این تفاوت که ستون <code>Cancel</code> که متغیر هدف مسئله است را در خود ندارد. مجموعه داده آزمایش ۴۳۲۹۳ سطر دارد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train_data.csv</code> و نمونه‌های آزمون که باید دسته‌ی آن‌ها را پیش‌بینی کنید در فایل <code>test_data.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از مجموعه داده آموزشی را به عنوان مجموعه داده اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train_data.csv')
train_data
# Out:
# (101017, 22)

# %%
test_data = pd.read_csv('../data/test_data.csv')
test_data
# Out:
#                        Created        DepartureTime    BillID   TicketID  \
# 0      2022-07-08 12:04:46.290  2022-08-16 23:59:00  38166794  2890395.0
# 1      2022-09-30 14:18:23.487  2022-09-30 23:59:00  39424175  7669420.0
# 2      2022-05-15 10:52:01.293  2022-06-06 17:40:00  37336619  2783057.0
# 3      2022-10-06 02:55:53.723  2022-10-14 19:45:00  39507715  7691289.0
# 4      2022-03-12 13:46:40.300  2022-03-12 19:30:00  36422079  6901256.0
# ...                        ...                  ...       ...        ...
# 43288  2022-09-25 15:33:09.793  2022-09-25 20:30:00  39338188  7647177.0
# 43289  2022-07-16 19:58:15.300  2022-07-18 21:45:00  38298325  7406150.0
# 43290  2022-06-16 18:14:40.673  2022-06-17 17:30:00  37823306  7274287.0
# 43291  2022-07-23 13:48:45.330  2022-08-23 21:05:00  38386540  2914007.0
# 43292  2022-08-14 11:04:39.597  2022-08-15 22:00:00  38674829  7514844.0
#
#        ReserveStatus    UserID   Male      Price  CouponDiscount  \
# 0                  2       NaN  False  2043000.0             0.0
# 1                  3       NaN  False  1220000.0             0.0
# 2                  2  800538.0   True  2132000.0             0.0
# 3                  5  950983.0  False   520000.0             0.0
# 4                  3       NaN   True  1180000.0             0.0
# ...              ...       ...    ...        ...             ...
# 43288              3       NaN   True  2480000.0             0.0
# 43289              3       NaN   True  1330000.0             0.0
# 43290              3       NaN   True  1290000.0             0.0
# 43291              2  724274.0   True  2810500.0             0.0
# 43292              3  610090.0   True  1700000.0             0.0
#
#                      From              To  Domestic  \
# 0                    مشهد           تهران         1
# 1                   تهران          اصفهان         1
# 2                    مشهد           تهران         1
# 3                   تهران           سمنان         1
# 4                  ارومیه        کرمانشاه         1
# ...                   ...             ...       ...
# 43288               تهران  مشهد (خراسان )         1
# 43289              اصفهان           شیراز         1
# 43290               تهران           رودسر         1
# 43291                مشهد           تهران         1
# 43292  خرم آباد (لرستان )             کرج         1
#
#                          VehicleType VehicleClass TripReason Vehicle  \
# 0              3 ستاره 6 تخته پارسي           NaN        Int   Train
# 1                              V I P         True        Int     Bus
# 2              4ستاره 4تخته سبز نوين          NaN        Int   Train
# 3                            اسکانیا         True       Work     Bus
# 4                   اسکانیا تک صندلی         True       Work     Bus
# ...                              ...          ...        ...     ...
# 43288           وای پی تخت شو ۲۵نفره         True        Int     Bus
# 43289  اسکانیا درسا(مانیتور اختصاصی)         True       Work     Bus
# 43290              مارال 25 نفره VIP         True        Int     Bus
# 43291           4 ستاره 4 تخته غزال           NaN        Int   Train
# 43292                مان 25 نفره VIP         True        Int     Bus
#
#       HashPassportNumber_p                                          HashEmail  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN  012dca1b2070c32e03238f49aa8f12a1a9ce580f8b1368...
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 43288                  NaN  7091c8c24f3f57b98561de5d9a874cb91c3fd44371930a...
# 43289                  NaN                                                NaN
# 43290                  NaN                                                NaN
# 43291                  NaN  a78e5ce63b34517a2c4e1d3ccd474241abe1993b49905c...
# 43292                  NaN                                                NaN
#
#         BuyerMobile  NationalCode
# 0      419509763088     660703096
# 1      935955347521     960594437
# 2      428059757595     854730165
# 3      515601565031     850531769
# 4      633910237635     893186872
# ...             ...           ...
# 43288   45595252975     158174797
# 43289  194871920550     384954737
# 43290  687841588584     648554818
# 43291  976918931561     779144272
# 43292  251061924518     146816459
#
# [43293 rows x 20 columns]

# %%
cols = ['CancelTime', 'UserID', 'VehicleType', 'VehicleClass', 'HashPassportNumber_p', 'HashEmail']

for col in cols:
    most_frequent = train_data[col].value_counts().sort_values(ascending=False).index[0]
    train_data[col].fillna(most_frequent, inplace=True)
    #print('All the missing values in column', col, 'are replaced with', most_frequent)
train_data.isna().sum()
# Out:
# Created                 0
# CancelTime              0
# DepartureTime           0
# BillID                  0
# TicketID                0
# ReserveStatus           0
# UserID                  0
# Male                    0
# Price                   0
# CouponDiscount          0
# From                    0
# To                      0
# Domestic                0
# VehicleType             0
# VehicleClass            0
# TripReason              0
# Vehicle                 0
# Cancel                  0
# HashPassportNumber_p    0
# HashEmail               0
# BuyerMobile             0
# NationalCode            0
# dtype: int64

# %%
cols = ['UserID', 'VehicleType', 'VehicleClass', 'HashPassportNumber_p', 'HashEmail']

for col in cols:
    most_frequent = test_data[col].value_counts().sort_values(ascending=False).index[0]
    test_data[col].fillna(most_frequent, inplace=True)
    #print('All the missing values in column', col, 'are replaced with', most_frequent)
test_data.isna().sum()
# Out:
# Created                 0
# DepartureTime           0
# BillID                  0
# TicketID                0
# ReserveStatus           0
# UserID                  0
# Male                    0
# Price                   0
# CouponDiscount          0
# From                    0
# To                      0
# Domestic                0
# VehicleType             0
# VehicleClass            0
# TripReason              0
# Vehicle                 0
# HashPassportNumber_p    0
# HashEmail               0
# BuyerMobile             0
# NationalCode            0
# dtype: int64

# %%
columns_time = ['Created', 'CancelTime', 'DepartureTime']
train_data[columns_time] = train_data[columns_time].apply(pd.to_datetime)
train_data['Created'] = train_data['Created'].dt.day_of_year
train_data['CancelTime'] = train_data['CancelTime'].dt.day_of_year
train_data['DepartureTime'] = train_data['DepartureTime'].dt.day_of_year
train_data.head()
# Out:
#    Created  CancelTime  DepartureTime    BillID   TicketID  ReserveStatus  \
# 0      207         130            207  38428546  7445571.0              3
# 1      300         300            302  39768762  7762719.0              5
# 2      255         130            276  39128001  2327596.0              5
# 3      220         130            220  38606546  7495440.0              3
# 4      305         130            307  39822185  2356902.0              5
#
#      UserID   Male      Price  CouponDiscount  ... Domestic  \
# 0  831022.0   True  1180000.0             0.0  ...        1
# 1  831022.0  False  1050000.0             0.0  ...        1
# 2  800398.0  False  4674000.0             0.0  ...        1
# 3  831022.0   True  1200000.0             0.0  ...        1
# 4  831022.0   True  6222000.0             0.0  ...        1
#
#                                          VehicleType  VehicleClass TripReason  \
# 0  VIPمانیتوردار-شارژراختصاصی تخت شو مارال (جدید)...          True       Work
# 1                                      classicus 2+2          True        Int
# 2                                           فوکر 100         False        Int
# 3            VIPدرسا+مانیتوردار+شارژراختصاصی+پذیرایی          True       Work
# 4                                4 ستاره اتوبوسي صبا         False       Work
#
#    Vehicle Cancel                               HashPassportNumber_p  \
# 0      Bus      0  42d6e83ca82b022cc5eb6b2d79ef7c1c810c6aacaf1ce0...
# 1      Bus      1  42d6e83ca82b022cc5eb6b2d79ef7c1c810c6aacaf1ce0...
# 2    Plane      0  42d6e83ca82b022cc5eb6b2d79ef7c1c810c6aacaf1ce0...
# 3      Bus      0  42d6e83ca82b022cc5eb6b2d79ef7c1c810c6aacaf1ce0...
# 4    Plane      0  42d6e83ca82b022cc5eb6b2d79ef7c1c810c6aacaf1ce0...
#
#                                            HashEmail   BuyerMobile  \
# 0  5021d7fb1dba2591b79d0421a8a2f3fb57186a65a7566c...  302222356019
# 1  5021d7fb1dba2591b79d0421a8a2f3fb57186a65a7566c...  900764168521
# 2  1c44d7a76b52341fa12dcfa993138576befcc9ebf01d14...  749804783291
# 3  5021d7fb1dba2591b79d0421a8a2f3fb57186a65a7566c...  781396205677
# 4  bb38b345aec02255e31d178492907175c5984f2a1f5b59...  524576220177
#
#   NationalCode
# 0    330024570
# 1    995520696
# 2    979382950
# 3    911237229
# 4    727496008
#
# [5 rows x 22 columns]

# %%
columns_time = ['Created', 'DepartureTime']
test_data[columns_time] = test_data[columns_time].apply(pd.to_datetime)
test_data['Created'] = test_data['Created'].dt.day_of_year
test_data['DepartureTime'] = test_data['DepartureTime'].dt.day_of_year
test_data.head()
# Out:
#    Created  DepartureTime    BillID   TicketID  ReserveStatus    UserID  \
# 0      189            228  38166794  2890395.0              2  831022.0
# 1      273            273  39424175  7669420.0              3  831022.0
# 2      135            157  37336619  2783057.0              2  800538.0
# 3      279            287  39507715  7691289.0              5  950983.0
# 4       71             71  36422079  6901256.0              3  831022.0
#
#     Male      Price  CouponDiscount    From        To  Domestic  \
# 0  False  2043000.0             0.0    مشهد     تهران         1
# 1  False  1220000.0             0.0   تهران    اصفهان         1
# 2   True  2132000.0             0.0    مشهد     تهران         1
# 3  False   520000.0             0.0   تهران     سمنان         1
# 4   True  1180000.0             0.0  ارومیه  کرمانشاه         1
#
#              VehicleType  VehicleClass TripReason Vehicle  \
# 0  3 ستاره 6 تخته پارسي           True        Int   Train
# 1                  V I P          True        Int     Bus
# 2  4ستاره 4تخته سبز نوين          True        Int   Train
# 3                اسکانیا          True       Work     Bus
# 4       اسکانیا تک صندلی          True       Work     Bus
#
#                                 HashPassportNumber_p  \
# 0  f0ccfdf146101cf946674a6f050f91cb2ec6d3b68ca4f6...
# 1  f0ccfdf146101cf946674a6f050f91cb2ec6d3b68ca4f6...
# 2  f0ccfdf146101cf946674a6f050f91cb2ec6d3b68ca4f6...
# 3  f0ccfdf146101cf946674a6f050f91cb2ec6d3b68ca4f6...
# 4  f0ccfdf146101cf946674a6f050f91cb2ec6d3b68ca4f6...
#
#                                            HashEmail   BuyerMobile  \
# 0  b9ff4532dffa777cc55613164bededd4b59904a364a7f1...  419509763088
# 1  b9ff4532dffa777cc55613164bededd4b59904a364a7f1...  935955347521
# 2  b9ff4532dffa777cc55613164bededd4b59904a364a7f1...  428059757595
# 3  012dca1b2070c32e03238f49aa8f12a1a9ce580f8b1368...  515601565031
# 4  b9ff4532dffa777cc55613164bededd4b59904a364a7f1...  633910237635
#
#    NationalCode
# 0     660703096
# 1     960594437
# 2     854730165
# 3     850531769
# 4     893186872

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43293 entries, 0 to 43292
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Created               43293 non-null  int64
#  1   DepartureTime         43293 non-null  int64
#  2   BillID                43293 non-null  int64
#  3   TicketID              43293 non-null  float64
#  4   ReserveStatus         43293 non-null  int64
#  5   UserID                43293 non-null  float64
#  6   Male                  43293 non-null  bool
#  7   Price                 43293 non-null  float64
#  8   CouponDiscount        43293 non-null  float64
#  9   From                  43293 non-null  object
#  10  To                    43293 non-null  object
#  11  Domestic              43293 non-null  int64
#  12  VehicleType           43293 non-null  object
#  13  VehicleClass          43293 non-null  bool
#  14  TripReason            43293 non-null  object
#  15  Vehicle               43293 non-null  object
#  16  HashPassportNumber_p  43293 non-null  object
#  17  HashEmail             43293 non-null  object
#  18  BuyerMobile           43293 non-null  int64
#  19  NationalCode          43293 non-null  int64
# dtypes: bool(2), float64(4), int64(7), object(7)
# memory usage: 6.0+ MB

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %%
# do some preprocessing 
from sklearn.preprocessing import OrdinalEncoder

categorical_cols = train_data.select_dtypes(include = "object").columns

enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

train_data[categorical_cols] = enc.fit_transform(train_data[categorical_cols])
test_data[categorical_cols] = enc.transform(test_data[categorical_cols])
train_data.head()
# Out:
#    Created  CancelTime  DepartureTime    BillID   TicketID  ReserveStatus  \
# 0      207         130            207  38428546  7445571.0              3
# 1      300         300            302  39768762  7762719.0              5
# 2      255         130            276  39128001  2327596.0              5
# 3      220         130            220  38606546  7495440.0              3
# 4      305         130            307  39822185  2356902.0              5
#
#      UserID   Male      Price  CouponDiscount  ...  Domestic  VehicleType  \
# 0  831022.0   True  1180000.0             0.0  ...         1       1126.0
# 1  831022.0  False  1050000.0             0.0  ...         1       1239.0
# 2  800398.0  False  4674000.0             0.0  ...         1       2082.0
# 3  831022.0   True  1200000.0             0.0  ...         1       1062.0
# 4  831022.0   True  6222000.0             0.0  ...         1        122.0
#
#    VehicleClass  TripReason  Vehicle  Cancel  HashPassportNumber_p  HashEmail  \
# 0          True         1.0      0.0       0                 217.0     5197.0
# 1          True         0.0      0.0       1                 217.0     5197.0
# 2         False         0.0      2.0       0                 217.0     1864.0
# 3          True         1.0      0.0       0                 217.0     5197.0
# 4         False         1.0      2.0       0                 217.0    12182.0
#
#     BuyerMobile  NationalCode
# 0  302222356019     330024570
# 1  900764168521     995520696
# 2  749804783291     979382950
# 3  781396205677     911237229
# 4  524576220177     727496008
#
# [5 rows x 22 columns]

# %%
mapping_male = {
    True: 1,
    False: 0
}

mapping_vehicle_class = {
    True: 1,
    False: 0
}

train_data['Male'] = train_data['Male'].map(mapping_male)
train_data['VehicleClass'] = train_data['VehicleClass'].map(mapping_vehicle_class)

test_data['Male'] = test_data['Male'].map(mapping_male)
test_data['VehicleClass'] = test_data['VehicleClass'].map(mapping_vehicle_class)
train_data.head()
# Out:
#    Created  CancelTime  DepartureTime    BillID   TicketID  ReserveStatus  \
# 0      207         130            207  38428546  7445571.0              3
# 1      300         300            302  39768762  7762719.0              5
# 2      255         130            276  39128001  2327596.0              5
# 3      220         130            220  38606546  7495440.0              3
# 4      305         130            307  39822185  2356902.0              5
#
#      UserID  Male      Price  CouponDiscount  ...  Domestic  VehicleType  \
# 0  831022.0     1  1180000.0             0.0  ...         1       1126.0
# 1  831022.0     0  1050000.0             0.0  ...         1       1239.0
# 2  800398.0     0  4674000.0             0.0  ...         1       2082.0
# 3  831022.0     1  1200000.0             0.0  ...         1       1062.0
# 4  831022.0     1  6222000.0             0.0  ...         1        122.0
#
#    VehicleClass  TripReason  Vehicle  Cancel  HashPassportNumber_p  HashEmail  \
# 0             1         1.0      0.0       0                 217.0     5197.0
# 1             1         0.0      0.0       1                 217.0     5197.0
# 2             0         0.0      2.0       0                 217.0     1864.0
# 3             1         1.0      0.0       0                 217.0     5197.0
# 4             0         1.0      2.0       0                 217.0    12182.0
#
#     BuyerMobile  NationalCode
# 0  302222356019     330024570
# 1  900764168521     995520696
# 2  749804783291     979382950
# 3  781396205677     911237229
# 4  524576220177     727496008
#
# [5 rows x 22 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
column_scaler = ['BillID', 'TicketID', 'UserID', 'Price', 'CouponDiscount', 'VehicleType', 'HashPassportNumber_p', 'HashEmail', 'BuyerMobile', 'NationalCode']
train_data[column_scaler] = scaler.fit_transform(train_data[column_scaler])
test_data[column_scaler] = scaler.transform(test_data[column_scaler])
train_data.head()
# Out:
#    Created  CancelTime  DepartureTime    BillID  TicketID  ReserveStatus  \
# 0      207         130            207  0.640748  0.950157              3
# 1      300         300            302  0.981829  0.997024              5
# 2      255         130            276  0.818757  0.193845              5
# 3      220         130            220  0.686048  0.957526              3
# 4      305         130            307  0.995425  0.198176              5
#
#      UserID  Male     Price  CouponDiscount  ...  Domestic  VehicleType  \
# 0  0.843845     1  0.006992             0.0  ...         1     0.357574
# 1  0.843845     0  0.006655             0.0  ...         1     0.393458
# 2  0.812447     0  0.016061             0.0  ...         1     0.661162
# 3  0.843845     1  0.007044             0.0  ...         1     0.337250
# 4  0.843845     1  0.020079             0.0  ...         1     0.038742
#
#    VehicleClass  TripReason  Vehicle  Cancel  HashPassportNumber_p  HashEmail  \
# 0             1         1.0      0.0       0              0.294038   0.312320
# 1             1         0.0      0.0       1              0.294038   0.312320
# 2             0         0.0      2.0       0              0.294038   0.112019
# 3             1         1.0      0.0       0              0.294038   0.312320
# 4             0         1.0      2.0       0              0.294038   0.732091
#
#    BuyerMobile  NationalCode
# 0     0.302219  3.370743e-10
# 1     0.900778  1.016787e-09
# 2     0.749815  1.000304e-09
# 3     0.781407  9.307029e-10
# 4     0.524580  7.430365e-10
#
# [5 rows x 22 columns]

# %%
train_data.describe()
# Out:
#              Created     CancelTime  DepartureTime         BillID  \
# count  101017.000000  101017.000000  101017.000000  101017.000000
# mean      200.754517     142.386084     206.727006       0.614896
# std        74.846507      40.316059      74.926240       0.279650
# min        31.000000      31.000000      14.000000       0.000000
# 25%       143.000000     130.000000     149.000000       0.388781
# 50%       216.000000     130.000000     223.000000       0.672865
# 75%       267.000000     130.000000     272.000000       0.865537
# max       307.000000     306.000000     348.000000       1.000000
#
#             TicketID  ReserveStatus         UserID           Male  \
# count  101017.000000  101017.000000  101017.000000  101017.000000
# mean        0.578957       3.163012       0.734959       0.610699
# std         0.356422       1.077199       0.222377       0.487594
# min         0.000000       2.000000       0.000000       0.000000
# 25%         0.270750       2.000000       0.730025       0.000000
# 50%         0.304798       3.000000       0.843845       1.000000
# 75%         0.948016       4.000000       0.843845       1.000000
# max         1.000000       5.000000       1.000000       1.000000
#
#                Price  CouponDiscount  ...       Domestic    VehicleType  \
# count  101017.000000   101017.000000  ...  101017.000000  101017.000000
# mean        0.012260        0.000345  ...       0.992100       0.287271
# std         0.018132        0.004902  ...       0.088529       0.303510
# min         0.000000        0.000000  ...       0.000000       0.000000
# 25%         0.006733        0.000000  ...       1.000000       0.038742
# 50%         0.008316        0.000000  ...       1.000000       0.134963
# 75%         0.011890        0.000000  ...       1.000000       0.537949
# max         1.000000        1.000000  ...       1.000000       1.000000
#
#         VehicleClass     TripReason        Vehicle         Cancel  \
# count  101017.000000  101017.000000  101017.000000  101017.000000
# mean        0.838136       0.559134       1.404922       0.151470
# std         0.368328       0.496493       1.402535       0.358508
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       2.000000       0.000000
# 75%         1.000000       1.000000       3.000000       0.000000
# max         1.000000       1.000000       3.000000       1.000000
#
#        HashPassportNumber_p      HashEmail    BuyerMobile  NationalCode
# count         101017.000000  101017.000000  101017.000000  1.010170e+05
# mean               0.295821       0.392897       0.503642  1.460141e-04
# std                0.033015       0.210706       0.287782  9.898357e-03
# min                0.000000       0.000000       0.000000  0.000000e+00
# 25%                0.294038       0.312320       0.257301  2.559402e-10
# 50%                0.294038       0.312320       0.504945  5.127587e-10
# 75%                0.294038       0.414423       0.750900  7.663628e-10
# max                1.000000       1.000000       1.000000  1.000000e+00
#
# [8 rows x 22 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
#     <br>
#     بر خلاف سایر تمرین‌های کالج، در این تمرین شما مجاز هستید از هر مدلی که آموخته‌اید استفاده کنید. به عبارت بهتر، هدف این سوال پیش‌بینی هرچه بهتر متغیر هدف مسئله است. انتظار ما این است که نحوه کار با کتابخانه‌های یادگیری ماشین را در حدی آموخته باشید که بتوانید با بهترین عملکرد، مسئله را حل کنید!
# </font>
# </p>

# %%
# modeling
from sklearn.model_selection import train_test_split

train_data = train_data.drop(columns=['CancelTime'])

target_col = 'Cancel'

x_train, x_val , y_train, y_val = train_test_split(train_data.drop(target_col,axis=1), train_data[target_col], test_size=.2,\
                                                   random_state=535, stratify=train_data[target_col])

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>f1_score</code> نام دارد.
#     <br>
#     این معیار، سنجه ارزیابی کیفیت مدل شماست. به عبارت بهتر در سامانه داوری هم از همین معیار برای نمره‌دهی استفاده شده است.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه داده آموزش یا اعتبارسنجی ارزیابی کنید.
# </font>
# </p>

# %%
# evaluate model
from sklearn.metrics import f1_score, classification_report, confusion_matrix
y_pred = model.predict(x_val)
f1_score(y_val, y_pred)
# Out:
# 0.9452924026753559

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>95%</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     پس از مهندسی ویژگی و مدلسازی، الگوریتمی دارید که می‌تواند شما را از متغیرهای مستقل به متغیر هدف برساند.
#     <br>
#     از این مدل برای پیش‌بینی نمونه‌های موجود در داده تست استفاده کنید و نتایج را در قالب جدول (<code>dataframe</code>) زیر آماده کنید.
# </font>
# </p>
#
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |------|---|
# |Cancel|آیا بلیط کنسل می‌شود یا نه|
#
# </font>
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     اسم دیتافریم باید <code>submission</code> باشد؛ در غیر این صورت، سامانه داوری نمی‌تواند تلاش‌ شما را ارزیابی کند.
#     <br>
#     این دیتافریم تنها شامل ۱ ستون با اسم <i>Cancel</i> است و ۴۳۲۹۳ سطر دارد.
#     <br>
#     به ازای هر سطر موجود در دیتافریم <i>test</i> شما باید یک مقدار پیشبینی شده داشته باشید.
#     <br>
#     جدول زیر، ۵ سطر ابتدایی دیتافریم <code>submission</code> را نشان می‌دهد. البته در جواب شما، مقادیر ستون <i>Cancel</i> ممکن است متفاوت باشد.
# </font>
# </p>
#
# <div style="text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# ||Cancel|
# |----|-----|
# |0|0|
# |1|0|
# |2|1|
# |3|1|
# |4|0|
#
# </font>
# </div>

# %%
# predict test samples

submission = model.predict(test_data)
submission = pd.DataFrame(submission, columns=['Cancel'])
submission
# Out:
#        Cancel
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# ...       ...
# 43288       0
# 43289       0
# 43290       0
# 43291       0
# 43292       0
#
# [43293 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)
            
submission.to_csv('submission.csv', index=False)
file_names = ['canceli.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['canceli.ipynb', 'submission.csv']
