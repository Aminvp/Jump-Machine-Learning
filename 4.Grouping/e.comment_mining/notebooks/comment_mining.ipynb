# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کامنت‌کاوی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این تمرین کاربردی قصد داریم به حل یک مسئله‌ی دنیای واقعی بپردازیم که از جمله مسائل حوزه‌ی <i>پردازش زبان طبیعی (Natural Language Processing یا به اختصار NLP)</i> به شمار می‌رود. در متن‌ها اطلاعات و مفاهیم بسیاری نهفته است که کشف و سامان‌دهی آن‌ها می‌تواند منجر به تولید ارزش‌های زیادی در کاربردهای مختلف شود. یکی از رایج‌ترین سناریوها این است که یک شرکت، وبسایت یا اپلیکیشن قصد دارد کامنت‌های کاربران درباره‌ی محصول یا محصولات خود را به شکل‌های مختلف تحلیل کند تا براساس نتایج به‌دست‌آمده استراتژی کاری خود را تعیین کند. از آنجا که در شرکت‌های بزرگ تعداد کامنت‌های دریافتی بسیار زیاد است و عملاً نیروی انسانی قادر به بررسی تمام آن‌ها نیست از یادگیری ماشین جهت تحلیل و تفسیر این داده‌ها استفاده می‌شود. به عنوان مثال یکی از مسائل کاربردی در این حوزه به این شکل تعیین می‌شود که ماشین موظف است یک کامنت را مطالعه کرده و پیش‌بینی کند که بصورت کلی آیا این کامنت حسی مثبت دارد یا خیر. مثلاً در ارتباط با یک محصول، آیا کاربر از خرید و محصول دریافتی خود رضایت داشته است یا خیر.  به این کاربرد <i>تحلیل احساس (Sentiment Analysis)</i> گفته می‌شود. یا یک مسئله‌ی دیگر که با نام <i>عقیده‌کاوی (Opinion Mining)</i> شناخته می‌شود، کشف عقیده‌ی کاربر در ارتباط با جنبه‌های مختلف یک چیز مثلاً یک محصول است. به عنوان مثال عقیده‌ی کاربر درباره‌ی کیفیت ساخت، گارانتی، قیمت و موارد این چنینی چه بوده است. در این تمرین نیز ما قصد داریم مدلی طراحی کنیم که بتواند صرفاً پیش‌بینی کند آیا در یک کامنت، صحبتی درباره‌ی قیمت یک محصول شده است یا خیر. پس اجازه دهید شروع کنیم و کامنت‌ها را بکاویم تا به قیمت برسیم!
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
# Out:
# /home/amin/Desktop/Jump Machine Learning/qenv/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده‌ای که در اختیار شما قرار گرفته مربوط به کامنت‌های ثبت‌شده در وب‌سایت دیجی‌کالا است. هرکدام از کامنت‌های موجود در این مجموعه از نظر اینکه آیا صحبتی از قیمت محصول در آن شده یا خیر برچسب‌گذاری شده است.  ۴۰۰۰۰ کامنت برچسب‌گذاری‌شده به عنوان داده‌های آموزشی و ۸۰۰۰ کامنت دیگر نیز به عنوان داده‌های آزمون در دسترس شماست.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>comment</code>|متن کامنت|
# |<code>price_value</code>|آیا درباره‌ی قیمت در آن صحبت شده (<code>1</code>) یا خیر (<code>0</code>)||
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train.csv</code> و نمونه‌های آزمون که باید برچسب آن‌ها را پیش‌بینی کنید در فایل <code>test.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از مجموعه‌ی آموزشی را به عنوان مجموعه‌ی اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train.csv') # To-Do
train_data
# Out:
#                                                  comment  price_value
# 0      قیمت مناسب وکیفیت خوب پیشنهادمیکنم حتما خرید کنید            1
# 1      به اندازه یک میلیمتر دورتادور گوشی خالی میماند...            0
# 2      از همه نظر عالی و یک خرید خوب در  قیمت حدود۴۰ ...            1
# 3      فقط یک بار هر یک ربع ساعت 1 درصد شارژ کرد بعدش...            0
# 4      قیمت این کالا خیلی تغییر میکنه . من خریدم چندر...            1
# ...                                                  ...          ...
# 39995  خیلی خوبه واسه گوشی m20ولی یه ترک از پایین داش...            0
# 39996  چند روزه دارم استفاده میکنم در یک کلام عالیه\r...            1
# 39997  من سی تومن خریدم و با توجه به قیمت ارزش خرید د...            1
# 39998  عالیه از هر نظر \nهم قیمتش کمه \nهم قطعاتش زیا...            0
# 39999  من برای داخل ماشین جاهای که دست نمیره خریدم یه...            0
#
# [40000 rows x 2 columns]

# %%
test_data = pd.read_csv('../data/test.csv') # To-Do
test_data
# Out:
#                                                 comment
# 0     با این قیمت بیرون جنس خوبی پیدا نمیشه، واقعا ر...
# 1     خیلی شیکه جنسش هم خوبه قابل استفاده است توصیه ...
# 2     خوب نیست بهتر میشه پیدا کرد به نظر من از هر لح...
# 3          شکل خوبی داره راضیم واسه جهیزیه دخترم خریدم
# 4     با توجه به اینکه گوشی رو برای مادرم خریدم و تو...
# ...                                                 ...
# 7995  بهترین کرم مرطوب کننده ای هست که برا دست تا ال...
# 7996  به نظر تو شگفت انگیز ارزش خرید داره البته خدای...
# 7997  از شیشه درآوردم و آبش رو هم خالی کردم گذاشتم ر...
# 7998  اصلا اونی نبود ک سفارش دادم یه مارک دیگه با یه...
# 7999  خیلی خوب بود برای من پر قدرته و سری های آرسی و...
#
# [8000 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# پیش‌پردازش متن و نحوه‌ی بازنمایی آن به شکل عددی یکی از تاثیرگذارترین عوامل در عملکرد مدل است. در پیش‌پردازش باید سعی کنیم متن را به گونه‌ای پاک‌سازی کنیم که ویژگی‌های مفیدتری در آن دیده شود و کلمات نادر و بی‌اهمیت از آن حذف شوند تا کار مدل راحت‌تر شود. علاوه بر این از آنجا که ماشین تنها قادر به محاسبات عددی است و درکی از رشته‌ها ندارد باید بتوانیم از کلمات موجود در متن ویژگی‌های عددی بامعنایی تولید کنیم و آن‌ها را به عنوان ورودی مدل خود در نظر بگیریم.
# <br>
#  تکنیک‌های پیش‌پردازش و پاک‌سازی متفاوتی برای متن وجود دارد که هم می‌توانید با جست‌وجو در اینترنت با آن‌ها آشنا شوید و هم می‌توانید از ایده‌های خلاقانه خودتان استفاده کنید. اما به چند نمونه از رایج‌ترین آن‌ها اشاره خواهیم کرد:
# </font>
# </p>
# <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <li><b>حذف کلمات توقف (stop words):</b> برخی کلمات هستند که در متن‌ها به تعداد بسیار زیادی تکرار می‌شوند اما بار معنایی خاصی ندارند و معمولاً در مسائل مرتبط با پردازش زبان نه تنها تاثیر مثبتی در عملکرد مدل نمی‌گذارند بلکه پرتکرار بودن آن‌ها ارزش زیادی را به این کلمات می‌دهد. از جمله‌ی این کلمات در فارسی می‌توان به «از»، «به»، «است»، «آنان»، «آخر»، «آنجا» و ... اشاره کرد. شما می‌توانید در متن خود با توجه به مسئله‌ای که تعریف می‌کنید نسبت به حذف این کلمات اقدام کنید. البته توجه داشته باشید که برخی کلمات می‌‍توانند بصورت رایج کلمه‌ی توقف شناخته شوند اما در مسئله‌ی خاص شما اتفاقاً با اهمیت باشند.</li>
# <li><b>حذف اعداد و حروف اضافه: </b>اعداد و حروف اضافه نیز همچون کلمات توقف ممکن است با توجه به مسئله بی‌اهمیت باشند و بتوان آن‌ها را به‌کلی حذف کرد. البته ایده‌ی دیگری وجود دارد که به‌جای هر عدد یک توکن خاص مثلاً <code>NUMBER</code> قرار دهید.</li>
# <li><b>نرمال‌سازی (normalization):</b> انجام برخی اصلاحات رایج در متن جهت نرمال کردن کلمات نیز تکنیک دیگری است که کاربرد زیادی دارد. به عنوان مثال در زبان فارسی رعایت نیم‌فاصله می‌تواند یک نرمال‌سازی بسیار مفید شناخته شود. اگر این کار صورت نگیرد به عنوان مثال کلمه‌ی «نیم فاصله» با کلمه‌ی «نیم‌فاصله» کاملاً متفاوت در نظر گرفته می‌شود. اولی خود شامل دو کلمه‌ی مجزاست در حالیکه دومی یک کلمه‌ی واحد است.</li>
# <li><b>ریشه‌یابی (stemming)</b> تکنیک دیگر تبدیل کلمات به ریشه‌ی آن‌هاست. به عنوان مثال در زبان فارسی «کتاب‌ها» را می‌توان با ریشه‌ی خود یعنی «کتاب» جایگزین کنیم. با این جایگزینی مفهوم کلمه عوض نخواهد شد اما کار ماشین با متن بسیار راحت می‌شود زیرا در این حالت بین این دو تمایزی قائل نمی‌شود.</li>
# </ul>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این قسمت از شما خواسته شده تا تابعی به نام <code>preprocessing</code> تعریف کنید که یک متن را به عنوان ورودی گرفته و سپس پیش‌پردازش‌های دلخواه شما بر روی آن انجام شود و در نهایت یک لیست از توکن‌های موجود در آن را برگرداند. منظور از توکن، هرکدام از اجزای موجود در متن است که کلمات، حروف،‌اعداد و... را  شامل می‌شود. به عنوان یک مثال اگر تابع شما جمله‌ی زیر را دریافت کند:
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <center>
# 'از همه نظر عالی و یک خرید خوب در  قیمت حدود۴۰ تومن'
# </center>
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# خروجی زیر برای آن تولید می‌شود: (توجه کنید که نیازی نیست خروجی تابع شما دقیقاً مشابه با این مثال باشد و مراحل پیش‌پردازش کاملاً به دلخواه شماست)
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <center>
# ['نظر', 'عالی', 'خرید', 'خوب', 'قیمت', 'تومن']
# </center>
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <b>نکته:</b> برای پیش‌پردازش متون فارسی کتابخانه‌ها و ابزارهای مختلفی وجود دارد که می‌توانید به دلخواه خود از آن‌ها استفاده کنید. با این حال یکی از رایج‌ترین کتابخانه‌ها <a href="https://www.roshan-ai.ir/hazm/" target=”_blank”>هضم</a> است که می‌توانید با نصب آن در محیط کار خود از ابزارهای موجود در آن بهره ببرید.
# برای دسترسی به لیست کلمات توقف فارسی می‌توانید به کمک <code>from hazm import stopwords_list</code>، لیست هضم را دریافت کنید.
# </font>
# </p>

# %%
from hazm import stopwords_list
txt = 'از همه نظر عالی و یک خرید خوب در قیمت حدود۴۰تومن'
def preprocessing(text):
    filtered = []
    # To-Do
    global lst
    lst = text.split(' ')
    for m in lst:
        if m not in stopwords_list():
            filtered.append(m)
    return filtered

preprocessing(txt)
# Out:
# ['خرید', 'قیمت', 'حدود۴۰تومن']

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این قسمت گام به گام به انجام محاسبات لازم جهت اجرای الگوریتم بیز ساده‌لوحانه (Naive Bayes) خواهیم پرداخت. در ابتدا نیاز است تا احتمال هر کلاس (<code>price_value</code> برابر <code>0</code> یا <code>1</code>) را محاسبه کنید. برای این کار تعداد داده‌های متعلق به آن کلاس را بر تعداد کل داده‌ها تقسیم کنید. حاصل را بصورت دیکشنری با فرمت <code dir=ltr>{0: P0, 1: P1}</code> در متغیر <code>prior_probability</code> ذخیره کنید. به جای <code>P0</code> احتمال برچسب <code>0</code> و به جای <code>P1</code> احتمال برچسب <code>1</code> را قرار دهید. <code>
# </font>
# </p>

# %%
y = train_data['price_value']
p0 = np.count_nonzero(y == 0)
p1 = np.count_nonzero(y == 1)
p = len(y)
P0 = p0 / p
P1 = p1 / p
prior_probability = {0: P0, 1: P1} # To-Do
prior_probability
# Out:
# {0: 0.520025, 1: 0.479975}

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال باید احتمال وقوع هر توکن در هر کلاس را به دست آوریم. برای این کار ویژگی ورودی مدل را تعداد رخداد یک توکن در نظر می‌گیریم. پس در ابتدا تابع <code>token_counter</code> را به گونه‌ای تکمیل کنید که مجموعه‌ای (آرایه‌ای) از متن‌ها را به عنوان ورودی گرفته و یک دیکشنری از تعداد رخداد هر کلمه در میان تمام آن‌ها تولید کند. یعنی به ازای هر متن موجود در ورودی، ابتدا آن را به تابع <code>preprocessing</code> بدهید تا پیش‌پردازش‌های مختلف را روی متن اعمال کند و توکن‌های موجود در آن را برگرداند. سپس به ازای هر توکن یک واحد به تعداد رخداد آن در دیکشنری اضافه کنید. فرمت دیکشنری شما باید به گونه‌ای باشد که نمایه‌ی آن، یک کلمه و مقدار آن، تعداد رخداد آن کلمه در میان تمام متون ورودی تابع باشد.
# </font>
# </p>

# %%
input = ['از همه نظر عالی و یک خرید خوب در قیمت حدود۴۰تومن', 'از همه نظر عالی و یک خرید خوب در قیمت حدود۴۰تومن', 'از همه نظر عالی و یک خرید خوب در قیمت حدود۴۰تومن']
def token_counter(texts):
    count_dict = {}
    # To-Do
    for m in texts:
        global ex
        ex = preprocessing(m)
        for e in ex:
            if e in count_dict.keys():
                count_dict[e] += 1
            else:
                count_dict[e] = 1        
    return count_dict

token_counter(input)
# Out:
# {'خرید': 3, 'قیمت': 3, 'حدود۴۰تومن': 3}

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون می‌توانید متون هرکدام از کلاس‌ها را به تابع <code>token_counter</code> بدهید تا تعداد رخداد هر کلمه در آن کلاس شمرده شود. یکبار کامنت‌هایی که برچسب <code>0</code> دارند را جدا کرده و به این تابع بدهید و خروجی را در متغیر <code>negative_class_count</code> ذخیره کنید. بار دیگر همین کار را برای برچسب <code>1</code> تکرار کرده و نتیجه را در متغیر <code>positive_class_count</code> ذخیره کنید.
# </font>
# </p>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <span style="color: green"><b>نکته: </b></span> در این تمرین اگر برخی سلول‌ها تا یک یا چند دقیقه طول کشیدند تعجب نکنید و به علت حجم بالای داده و محاسبات طبیعی است.
# </font>
# </p>

# %%
label_zero = train_data[train_data.price_value == 0]
lable_one = train_data[train_data.price_value == 1]
negative_class_count = token_counter(label_zero.comment) # To-Do
negative_class_count
# Out:
# {'اندازه': 772,
#  'میلیمتر': 16,
#  'دورتادور': 1,
#  'گوشی': 990,
#  'خالی': 120,
#  'میماند': 5,
#  'قاب': 172,
#  'استفاده': 2963,
#  'پوشش': 68,
#  'خواهد': 30,
#  'ربع': 6,
#  'ساعت': 326,
#  '1': 39,
#  'درصد': 81,
#  'شارژ': 434,
#  'بعدش': 60,
#  'دیگه': 1082,
#  'کلا': 310,
#  'نکرد\n': 2,
#  'راحت': 506,
#  'نرم': 460,
#  'زیبا': 431,
#  'قیمت': 477,
#  'نکردم': 347,
#  'ریز': 122,
#  'هستش': 449,
#  '': 4680,
#  'هفته': 214,
#  'هست': 2344,
#  'خریدم': 1499,
#  'تبلتهای': 1,
#  'موجود': 154,
#  'بازار': 171,
#  'خریدش': 171,
#  'مقرون': 6,
#  'بصرفه': 12,
#  'هست،': 92,
#  'صفحه': 258,
#  'نمایش': 74,
#  'کیفیت،': 7,
#  'سرعت': 180,
#  'هنگی،': 1,
#  'کارای': 42,
#  'کامپیوترو': 1,
#  'میشه': 1686,
#  'انجام': 149,
#  'موبایل': 94,
#  'مطالعه.': 1,
#  'مناطق': 5,
#  'سردسیر': 1,
#  'هوای': 17,
#  'سرد': 35,
#  'رادیاتور': 3,
#  'نمیخوره': 165,
#  'نتیجه': 57,
#  'بخاری': 13,
#  'ماشین': 212,
#  'خوبه': 2682,
#  'گرم': 169,
#  'میکنه\nیا': 1,
#  'اگه': 650,
#  'معتدل': 3,
#  'هستین': 22,
#  'زمستان': 21,
#  'بخاری\nمن': 1,
#  'وقته': 28,
#  'گرفتم': 969,
#  'ازش': 730,
#  'راضی': 1485,
#  'هستم': 381,
#  'ترس': 11,
#  'واقعاً': 44,
#  'خوبو': 8,
#  'قشنگوراحته.': 1,
#  'البتع': 1,
#  'رنگای': 23,
#  'بولیز': 1,
#  'یه': 2028,
#  'مقدار': 165,
#  'له': 33,
#  'قسمتای': 1,
#  'یفید': 1,
#  'رنگ': 1666,
#  'میده': 446,
#  'اروم': 3,
#  'دست': 605,
#  'آب': 310,
#  'خنک': 35,
#  'شست،': 1,
#  'قشنگ': 295,
#  'برا': 402,
#  'یلدا': 13,
#  'سلام': 452,
#  'ظاهرش': 91,
#  'جنس': 1283,
#  'گیره': 86,
#  'بدردبخور': 1,
#  'موهارو': 37,
#  'نمیگیره': 38,
#  'زودهم': 2,
#  'میشکنه': 26,
#  'اگ': 21,
#  'حواستون': 40,
#  'نباشه': 75,
#  'طعم': 245,
#  'داره،': 102,
#  'قوامش': 1,
#  'کمتر': 154,
#  'ماست': 19,
#  'یونانی': 1,
#  'قبلاً': 30,
#  'گرفتم،': 31,
#  'اصطلاع': 1,
#  'شله': 10,
#  'اصلا': 1623,
#  'نیانداخت.': 1,
#  'بودممنون': 3,
#  'براc7ام': 1,
#  'موجودکردیدتوبازارراحت': 1,
#  'پیدانمیشد.': 1,
#  'اسلایم': 37,
#  'یکم': 538,
#  'سفت': 107,
#  'بود\n': 8,
#  'کیفیت': 2358,
#  'ساخته': 56,
#  '.': 1303,
#  'جلوش': 11,
#  'سنگینتره': 1,
#  'خسته': 40,
#  'نشه': 99,
#  'جلوی': 45,
#  'عرق': 28,
#  'لیز': 32,
#  'خوردن': 42,
#  'مداد': 47,
#  'میگیره': 120,
#  'شیک': 234,
#  '\r\nبرای': 28,
#  'دیوار': 50,
#  'مناسبه': 235,
#  'کلیپس\n': 1,
#  'کوچکتر': 83,
#  'اون': 588,
#  'ک': 630,
#  'انتظار': 231,
#  'داشتم': 431,
#  'ظریف': 80,
#  'تر': 649,
#  'معمولی': 326,
#  'رنگهاش': 14,
#  'واقعا': 1323,
#  'کاغذ': 141,
#  'بود.': 513,
#  'راضیم': 440,
#  '\r\nنسبت': 6,
#  'است\r\nممنون': 6,
#  'بچه': 433,
#  'های': 1654,
#  'دی': 197,
#  'جی\r\nخدا': 5,
#  'قوت': 27,
#  'خوشگل': 145,
#  'خریدم،': 39,
#  'خوشگلن': 14,
#  '،': 1093,
#  'نقلی': 5,
#  'ان': 71,
#  'دنبال': 106,
#  'سایز': 830,
#  'پیاله': 8,
#  'هستید': 51,
#  '،نگیریدش،': 1,
#  'نهایتا': 14,
#  '۱/۵': 3,
#  'قاشق': 32,
#  'غذاخوری': 5,
#  'مربا': 6,
#  'توش': 234,
#  'میشه،': 44,
#  'واقع': 41,
#  'یکنفره': 1,
#  'مجموع': 68,
#  'خریدشون': 4,
#  'هستم.': 73,
#  'امیدوارم': 162,
#  'نظرم': 418,
#  'مفید': 44,
#  'باشه.من': 1,
#  'دانگلو': 1,
#  'کامپیوتر': 38,
#  'ویندوز': 28,
#  '10': 58,
#  'نسخه': 34,
#  'pro': 9,
#  'وصل': 207,
#  'نصب': 323,
#  'cd': 4,
#  'فورا': 6,
#  'کار': 1298,
#  'شبکه': 26,
#  'اطراف': 23,
#  'شناسایی': 10,
#  'کرد.مودم': 1,
#  'فاصله': 49,
#  'ی': 597,
#  '6': 35,
#  'متری': 31,
#  'قرار': 200,
#  'سر': 337,
#  'راهش': 5,
#  'انتن': 11,
#  'فول': 16,
#  'تست': 124,
#  'موضوع': 33,
#  'تایید': 31,
#  'کرد.همچنین': 1,
#  'دانگل': 12,
#  'اشتراک': 12,
#  'فایل': 19,
#  'شیرایت': 1,
#  'ها': 1447,
#  'ذکر': 58,
#  'سرعن': 1,
#  '150': 7,
#  'مگابیت': 2,
#  'ثانیه': 42,
#  'منتقل': 12,
#  'لپ': 79,
#  'تاپ': 69,
#  'قطعی': 28,
#  'مشکلی': 297,
#  'شد.\r\nاین': 1,
#  'بگم': 227,
#  'نمونه': 87,
#  'میکرو': 8,
#  'نانو': 3,
#  'عمر': 60,
#  'تری': 41,
#  'خاطر': 160,
#  'دفع': 4,
#  'حرارت': 46,
#  'قطعات': 50,
#  'آن.\r\nاین': 1,
#  'رابط': 25,
#  'امنیتی': 4,
#  'نسل': 10,
#  'آخر': 46,
#  'بهره': 3,
#  'برده': 10,
#  'دکمه': 141,
#  'wps': 2,
#  'بدنه': 164,
#  'اتصال': 84,
#  'آسان': 14,
#  'سریع': 193,
#  'میشود.': 10,
#  'خوش': 447,
#  'بو': 133,
#  '...و': 1,
#  'حجم': 112,
#  'مایع': 70,
#  'لباس': 152,
#  'تمیز': 293,
#  'میشن': 51,
#  'واسه': 516,
#  'زاپاس': 6,
#  'مال': 63,
#  'بنده': 106,
#  'زود': 335,
#  'خراب': 303,
#  'جنسش': 696,
#  'باری': 24,
#  'سفارش': 1304,
#  'دادم': 935,
#  'اشتباه': 135,
#  'ارسال': 592,
#  'مرجوع': 727,
#  'کردم.': 138,
#  'دهی': 52,
#  'بودم\nولی': 2,
#  'تابم': 3,
#  'خورد': 131,
#  '\r\nولی': 46,
#  'فلش': 80,
#  '\r\nو': 47,
#  'تصویر': 294,
#  'فرق': 252,
#  'سایزش': 291,
#  'استاندارد': 72,
#  'لارجش': 5,
#  '2xl': 2,
#  'خواهرم': 50,
#  'هدیه': 189,
#  'راضیه': 22,
#  'تربیت': 1,
#  'فرزندان': 3,
#  'عطر': 101,
#  'سلیقه': 91,
#  'ایه': 35,
#  'بخاطره': 4,
#  'بسته': 1089,
#  'زیباش': 4,
#  'ظاهرا': 24,
#  'عطرش': 13,
#  'معلوم': 73,
#  'مواد': 97,
#  'داخلش': 192,
#  'تازه': 280,
#  'کاسکوی': 1,
#  'عاشقه': 2,
#  'خوراکیای': 2,
#  'داخلشه': 2,
#  'عنوان': 225,
#  'جایزه': 2,
#  'روزی': 50,
#  'مشت': 6,
#  'بهش': 198,
#  'میدم': 106,
#  'ذوق': 63,
#  'داره': 3008,
#  'انقدز': 1,
#  'جلدسو': 1,
#  'میشناسه': 1,
#  'دستکش': 38,
#  'پشم': 11,
#  'نمی': 356,
#  'باشد.': 36,
#  'بلند': 140,
#  'تره': 107,
#  'نصف': 71,
#  'کابل': 246,
#  'شارژرمو': 1,
#  'پوشونده': 3,
#  'خر': 5,
#  'خونه': 182,
#  'مونوپولی': 1,
#  'باشه\r\nبزرگ': 1,
#  'کوچیک': 378,
#  'نداره': 953,
#  'چیر،رنگ': 1,
#  'دقیقا': 223,
#  'همون': 323,
#  'بودم': 811,
#  'لامپ': 88,
#  'پلاستیکی': 125,
#  'آرمیچر': 3,
#  'منشور': 1,
#  'میکنه': 885,
#  'اصلی': 139,
#  'داره\r\nمن': 7,
#  'هفت': 44,
#  'داخل': 439,
#  'رنگه': 52,
#  'فهمیدم': 24,
#  'ثابت': 48,
#  'هستش\r\nبه': 1,
#  'میاوردن': 1,
#  'ابی': 43,
#  'بود\r\nدر': 6,
#  'خوشگله': 164,
#  'ظاهر': 158,
#  'چندان': 32,
#  'جالب': 200,
#  'خودمم': 17,
#  'مردانشو': 1,
#  'ماسک': 159,
#  '\nبند': 1,
#  'هاش': 324,
#  'کنده': 127,
#  'نمیشه': 458,
#  'پیشنهاد': 673,
#  'میکنم': 1289,
#  'حتما': 528,
#  'بخرید': 352,
#  'غذا': 46,
#  'حقیقت': 8,
#  'شکم': 10,
#  'ارزش': 240,
#  'تغذیه': 7,
#  'ای': 1041,
#  'جوره': 33,
#  'غذای': 15,
#  'خشک': 299,
#  'فله': 14,
#  'بهتره.': 33,
#  'حمایت': 19,
#  'سگ': 19,
#  'سرپرست': 2,
#  'درد': 309,
#  'آپارتمانی': 3,
#  'خوره.': 3,
#  'سگتون': 2,
#  'خوره': 49,
#  'صرفه': 48,
#  'جویی': 5,
#  'هزینه': 116,
#  'باشین': 66,
#  'غذاهای': 5,
#  'ناسالم': 3,
#  'اسکلت': 4,
#  'مرغ': 49,
#  'نرید': 5,
#  'همراه': 122,
#  'پختنی': 1,
#  'مکمل': 3,
#  'کنید.': 88,
#  'شرکت': 103,
#  'مدل': 504,
#  '29': 2,
#  'پروتئین': 3,
#  'تولید': 152,
#  'کیسش': 2,
#  'سیاهه': 3,
#  'مراتب': 6,
#  'اینه': 222,
#  'اختلاف': 16,
#  'چندانی': 18,
#  'ندارن': 47,
#  'توصیه': 482,
#  'میکنم.': 87,
#  'عکس': 988,
#  'ژل': 38,
#  'تصویرخیلی': 1,
#  '،ولی': 21,
#  'فرستادن': 304,
#  'کردم،داخل': 1,
#  'حرف': 105,
#  'Q': 1,
#  'تیوپ': 8,
#  'نقطه': 67,
#  'باشه': 883,
#  '،سفیدک': 1,
#  'میزنه': 121,
#  'خانونی': 1,
#  'کتاب': 644,
#  'بخونه': 12,
#  'دریک': 2,
#  'کلام': 24,
#  'عالیه': 1058,
#  'زمانی': 47,
#  'تاریخ': 154,
#  'انقضا': 29,
#  'درج': 39,
#  'ماه': 298,
#  'گذشته': 56,
#  'الان': 425,
#  'دستم': 645,
#  'شل': 102,
#  'کوچیکه': 300,
#  '5ساله': 1,
#  'بد': 661,
#  'منکه': 40,
#  'خوشم': 217,
#  'نیامد': 8,
#  'اصلااااااااااا': 1,
#  'زندگی': 46,
#  'ام': 356,
#  'همچین': 64,
#  'خیارشوری': 1,
#  'نخورده': 19,
#  '\r\nافتضااااااااح': 1,
#  'نبود....برای': 1,
#  'پوست': 441,
#  'چرب': 126,
#  'جوش': 138,
#  'حالت': 276,
#  'چسب': 294,
#  'دستیه': 9,
#  'چیزش': 54,
#  '🥰🥰🥰': 1,
#  'شک': 137,
#  'صندلی': 20,
#  'تعویض': 63,
#  'دیدم': 240,
#  'مشابه': 89,
#  'تیبا': 10,
#  'فست': 25,
#  'برام': 334,
#  'شارژر': 125,
#  'اومد': 288,
#  '2': 82,
#  'بعدشم': 6,
#  'داغ': 81,
#  '\r\nکلا': 8,
#  'پول': 160,
#  'ریختنه': 5,
#  'وگرنه': 93,
#  'پلاستیکش': 35,
#  'بدرد': 178,
#  'نخوره': 30,
#  'راحیه': 1,
#  'دل': 41,
#  'نشین': 4,
#  'قدرت': 120,
#  'بدست': 13,
#  'یکمش': 1,
#  'ریخته': 65,
#  'نداشتم': 159,
#  'واس': 24,
#  'همسن': 1,
#  'ستاره': 14,
#  'قشنگتر': 10,
#  'عکسشه': 17,
#  'اکلیلهای': 1,
#  'شفافتر': 1,
#  'عکسه.': 5,
#  'پاکت': 24,
#  'دقت': 373,
#  'مشخصه': 51,
#  'قلاب': 5,
#  'آویز': 12,
#  'کاشی': 11,
#  'زدن.': 2,
#  'حدودا': 29,
#  '۱۰×۱۰': 1,
#  '\r\nدر': 45,
#  'حین': 21,
#  'مکالمه': 35,
#  'صدا': 231,
#  'میاد': 261,
#  'ضعیف': 203,
#  'میره': 131,
#  'نکته': 86,
#  'ایفون': 19,
#  '7': 22,
#  'صدای': 183,
#  'موزیک': 29,
#  'لپتاپ': 36,
#  'اندروید': 27,
#  'صداش': 105,
#  'سلام\r\nچسبندگی': 1,
#  'فک': 100,
#  'نازکه': 106,
#  'بقیه': 209,
#  'چسبا': 3,
#  'نمیدونم': 224,
#  'نازکیشو': 1,
#  'اسم': 48,
#  'سوشرت': 1,
#  'تابستانه': 2,
#  'باشه،': 32,
#  'همونه،': 1,
#  'بهار': 24,
#  'تابستان،': 1,
#  'تن': 64,
#  'خور': 23,
#  'والا': 22,
#  'بخاطر': 186,
#  'نظرات': 162,
#  'مثبت': 33,
#  'اکثر': 34,
#  'دوستان': 338,
#  'خودم': 316,
#  'درمورد': 12,
#  'عسل': 27,
#  'عسلهای': 1,
#  'یکیش': 75,
#  'مجبور': 128,
#  'شدم': 308,
#  'بدم': 135,
#  '۱۵': 25,
#  'تومان': 39,
#  'خرید': 807,
#  'اولی': 30,
#  'شیشه': 168,
#  'دومی': 33,
#  'ماشینو.من': 1,
#  'صندوق': 25,
#  'ساینا': 5,
#  'زدم': 156,
#  'الکتریسیته': 4,
#  'ایجاد': 93,
#  'تاثیر': 90,
#  'خاصی': 130,
#  'بودم.': 50,
#  'جذب': 139,
#  'بدن': 71,
#  'میکنه.': 92,
#  'مونه': 20,
#  'درازمدت': 1,
#  'میگذاره': 1,
#  'تدریج': 1,
#  'متوجه': 129,
#  'میشید': 27,
#  'پوستتون': 15,
#  'دیرتر': 13,
#  'میشه.': 119,
#  'بوی': 499,
#  'ملایمی': 21,
#  '6ماه': 3,
#  'اینو': 213,
#  'فروشگاه': 49,
#  'تقویت': 21,
#  'موتورتون': 2,
#  'بودم،': 31,
#  'مشکل': 289,
#  'شدم،': 7,
#  'خدمات': 25,
#  'گارانتی': 123,
#  'زنگ': 78,
#  'راهنماییم': 3,
#  'مشکلم': 8,
#  'شد،': 28,
#  'الآنم': 1,
#  '۲': 120,
#  'هفتست': 2,
#  'ژلو': 1,
#  'منتظر': 13,
#  'موندم': 8,
#  'نتیجرو': 1,
#  'بگم.این': 1,
#  'شستشو': 49,
#  'نظیره': 20,
#  'عرض': 75,
#  '۳': 138,
#  'روز': 429,
#  'جدیدی': 7,
#  'زدید': 1,
#  'میبره': 32,
#  'میکنه.من': 3,
#  'قهوه': 136,
#  'صورتم': 45,
#  'داشتمممم': 1,
#  'عمل': 68,
#  'توی': 755,
#  'جوشامو': 1,
#  'کردع': 1,
#  'داره.از': 3,
#  'سینره': 10,
#  'هیدرودرمم': 1,
#  'بخوام': 24,
#  'اولویت': 4,
#  'بزارم:درمالیفت-سینره-هیدرودرم': 1,
#  'عشقم': 1,
#  'قناری': 3,
#  'هام': 62,
#  'خروس': 1,
#  'بلدرچین': 3,
#  'عاشق': 47,
#  'میل': 25,
#  'ورمها': 1,
#  'هستن': 182,
#  'باورم': 11,
#  'اینقدر': 74,
#  'استقبال': 8,
#  'کنن،': 1,
#  'بهداشتیه': 6,
#  'سومه': 5,
#  'براشون': 18,
#  'گرفتم.': 47,
#  'تشویقی': 5,
#  'تخم': 33,
#  'گذاریشون': 1,
#  'عالیه\u200c.': 1,
#  'چیزیه': 31,
#  'میخواستم': 160,
#  'جادار': 29,
#  'هک': 6,
#  'چادری': 1,
#  'دونه': 91,
#  'لامپا': 3,
#  'ضروریه': 9,
#  'درست': 398,
#  'کاسه': 26,
#  'مد': 27,
#  'تصورم': 10,
#  'گرچه': 5,
#  'ابرو': 36,
#  'مناسبه\nمن': 1,
#  'خانگی': 29,
#  'جعبه': 334,
#  'نداشت.کف': 1,
#  'ظرف': 122,
#  'تماما': 1,
#  'خط': 168,
#  'وخش': 2,
#  '.انگار': 1,
#  'ظروف': 24,
#  'مرجوعی': 124,
#  'بوده.در': 1,
#  'میشوریم': 1,
#  'اتفاقی': 20,
#  'براش': 114,
#  'نیفتاده': 7,
#  'رنگهای': 33,
#  'تزیینی': 4,
#  'رنگش': 476,
#  'زیباست': 168,
#  'ندرت': 3,
#  'عالیه.\nواقعا': 1,
#  'سرگرم': 59,
#  'میکنه.\nبهتره': 1,
#  'موقع': 324,
#  'محلول': 27,
#  'اضافه': 83,
#  'بدید.': 13,
#  'مطمئن': 56,
#  'داره.': 276,
#  '\u200cکسانی': 1,
#  'محبوب': 5,
#  'خوبیه.': 39,
#  'نخوندمش': 11,
#  'ب': 254,
#  'جلد': 85,
#  'زیبایی': 211,
#  'سالم': 208,
#  'تحویل': 218,
#  'مرسی': 55,
#  'مخصوصاً': 8,
#  'بچم': 14,
#  'تبلت': 52,
#  'ایپدت': 1,
#  'وجنس': 15,
#  'وکاربریش': 1,
#  'هرچی': 63,
#  'وسیله': 124,
#  'ریزازجمله': 1,
#  'هنسفری': 2,
#  'سیم': 209,
#  'وباسیم': 1,
#  'شارژوهمچنین': 1,
#  'گذاشتن': 73,
#  'وسایل': 72,
#  'ریزمثل': 1,
#  'انگشترساعت': 1,
#  'خلاصه': 57,
#  'زیادداره': 1,
#  'وهمچنین': 4,
#  'بسیارارزان': 1,
#  'دیجی': 1285,
#  'بودباتشکرخداقوت': 1,
#  'صندل': 8,
#  'شیکی': 29,
#  'است،': 38,
#  'مردمی': 1,
#  'بزرگتر': 241,
#  'دستگاه': 305,
#  'دوامی': 4,
#  'هس': 33,
#  'لک': 40,
#  'قسمتی': 36,
#  'بدنم': 8,
#  'خارش': 17,
#  'حس': 145,
#  '۲۰': 42,
#  'روشن': 292,
#  'نرفت': 13,
#  'دومه': 14,
#  'دارم': 518,
#  'کاپ': 6,
#  'میکنم\r\nیعنی': 1,
#  'شب': 69,
#  'پریودی': 1,
#  'انقد': 32,
#  'مث': 16,
#  'خوابیدم\r\nبهترین': 1,
#  'زندگیم': 2,
#  'الان\r\n\r\nبعید': 1,
#  'میدونم': 23,
#  'باشه\r\nدیگه': 1,
#  'خیسی': 4,
#  'خونریزی\r\nوااای': 1,
#  'چقدر': 74,
#  'عالیه\r\nهیچوقت': 1,
#  'نمیکردم': 62,
#  'دوره': 25,
#  'عادی': 32,
#  'باشه\r\nالان': 1,
#  'خییییییلی': 4,
#  'خوشحالم\r\nتازه': 1,
#  'دیشب': 7,
#  'مهمون': 1,
#  'داشتم\r\nانقد': 1,
#  'ریلکس': 3,
#  'خدا': 45,
#  'میدونه\r\nبا': 1,
#  'قاطعیت': 3,
#  'میگم': 46,
#  'نکنید': 143,
#  'فعلا': 139,
#  'فصل': 40,
#  'هفتم': 2,
#  'خوندم': 64,
#  'غصه': 1,
#  'خوردم': 30,
#  'روزانه': 47,
#  'بخواد': 20,
#  'مژه': 43,
#  'سیاه': 103,
#  'بشه': 443,
#  'چهره': 7,
#  'طبیعی': 48,
#  'دوخت': 152,
#  'شکیلی': 4,
#  'کلاه': 48,
#  'فرستاده': 121,
#  'فیله': 4,
#  'خریم': 2,
#  'پاک': 212,
#  'نداشته': 131,
#  'باشه.': 80,
#  'نشده': 212,
#  'عصب': 1,
#  'جدا': 172,
#  'چاقویی': 4,
#  'تیز': 55,
#  'میخواین': 37,
#  'تیزتر': 3,
#  'می\u200cکنه': 59,
#  'اسپری': 88,
#  'فوم': 27,
#  'لاستیک': 19,
#  'دیرگون': 1,
#  'مارکای': 2,
#  'ایرانی': 145,
#  'بخیلی': 1,
#  'بهتره': 238,
#  'تراشکارم': 1,
#  'میکرومتر': 1,
#  'میلیونی': 5,
#  'برابری': 11,
#  'دقیق': 117,
#  'باکیفیت': 69,
#  'تستش': 12,
#  'صدم': 2,
#  'ژاپنی': 4,
#  'دوامش': 21,
#  'گوشت': 65,
#  'خوبیه': 482,
#  'کاش': 225,
#  'گزینه': 88,
#  'کالا': 1485,
#  'میزدی': 1,
#  'قلم': 55,
#  'سفارشتو': 1,
#  'کنسل': 5,
#  'میکرد': 76,
#  'اشپزخونه': 5,
#  'لازمه.رنگش': 1,
#  'نمیکنم': 200,
#  'تعریف': 80,
#  'باشه\nاگه': 1,
#  'نخوندین': 2,
#  'بخونینش\nتگر': 1,
#  'نکنین': 23,
#  'ترجمه\u200cی': 1,
#  'بدش': 10,
#  'هست.': 250,
#  'ترجمه\u200cش': 1,
#  'جورابی': 3,
#  'کدوم': 43,
#  '\r\nاگر': 9,
#  'دمشون': 4,
#  'داخلی.': 1,
#  'دفترچه': 31,
#  'اموزش': 8,
#  'حرکات\nفقط': 1,
#  'بادش': 12,
#  'میخوره': 190,
#  'میدانستم': 1,
#  'اینقد': 17,
#  'است،هرگز': 1,
#  'نمیخریدم.': 1,
#  'نخ': 99,
#  'کش': 126,
#  'کوتاهتر': 5,
#  'معمول': 13,
#  'بازحمت': 1,
#  'معجزه': 12,
#  'ندااشته': 1,
#  'باشید\r\n': 1,
#  'دستورالعمش': 1,
#  'راهنمایی': 19,
#  'نکرده.': 3,
#  'ور': 9,
#  'بری': 13,
#  'بیاد.': 8,
#  'آرد': 2,
#  'ومخمر': 1,
#  '۴-۵': 2,
#  'پیتزای': 2,
#  'متوسط': 98,
#  'کافیه.': 3,
#  'بنظر': 98,
#  'تموم': 88,
#  'اب': 98,
#  'کردنش': 55,
#  'مشبک': 4,
#  'نازک': 242,
#  'فرستادند': 20,
#  '5': 71,
#  '4تا': 2,
#  '۱': 54,
#  'سال': 289,
#  'خورده': 113,
#  'قشنگی': 106,
#  'تیزه': 31,
#  'دسته.': 8,
#  'اندازش': 131,
#  'مناسبه\r\nچون': 1,
#  'رسیده': 93,
#  'نطره': 1,
#  'فنی': 52,
#  'تاییدش': 3,
#  'نظرب': 1,
#  'اای': 1,
#  'نوجوون': 1,
#  'متن': 45,
#  'بگیرن.': 2,
#  'دایم': 4,
#  'شسته': 34,
#  'شه': 110,
#  'الکل': 47,
#  'زده': 142,
#  'کرم': 275,
#  'آبرسان': 21,
#  'تجدیدش': 1,
#  'کنی': 146,
#  'لازمه': 58,
#  'بوش': 130,
#  'دوست': 357,
#  'ندارم.': 13,
#  'نمکه،': 2,
#  'جنسشم': 70,
#  'خوبه،': 102,
#  'درکل': 128,
#  'جوراب': 56,
#  'کیوتیه': 1,
#  'امکانات': 22,
#  'دوربین': 187,
#  'پردازنده': 20,
#  'سطل': 29,
#  'میز': 73,
#  'جوابگو': 12,
#  'کنندگی': 73,
#  'داره\r\nبا': 3,
#  'پد': 63,
#  'لاک': 41,
#  'پررنگ': 24,
#  'راحتی': 176,
#  'میشه\r\nبوی': 1,
#  'باشه\r\nیه': 1,
#  'مات': 92,
#  'نظرات،': 2,
#  'دستمال': 89,
#  'کاغذی': 33,
#  'کیفیتیه،': 1,
#  'پودر': 73,
#  'چندبار': 30,
#  'محصول': 787,
#  'تاثیرشو': 6,
#  'گذاشت': 20,
#  'موهام': 68,
#  'وز': 15,
#  'پژوه': 1,
#  '206': 11,
#  'sd': 2,
#  'کارامد': 8,
#  '\r\n': 48,
#  'برسیش': 2,
#  'نو': 33,
#  'هربار': 21,
#  '۱۰': 87,
#  'دیقه': 10,
#  'سرش': 47,
#  'ترک': 76,
#  'برداشته': 21,
#  'انعطاف': 36,
#  'پذیر': 12,
#  'بادیرن': 1,
#  'ذهنتون': 3,
#  'خطور': 1,
#  'میکنه\r\n': 2,
#  'انتخاب': 230,
#  'نیس': 149,
#  'چراغ': 80,
#  'اعداد': 6,
#  'سختی': 56,
#  'خوانده': 3,
#  'طوسی': 56,
#  'دادم؛و': 1,
#  'بود...': 13,
#  'قطعاتی': 2,
#  'میتونید': 120,
#  'خمیری': 3,
#  'شبیه': 219,
#  'بازسازی': 3,
#  'است.': 203,
#  'تکه': 36,
#  'دستگیره': 18,
#  'شکسته': 236,
#  'ضمیمه': 2,
#  'ببینید.': 7,
#  'قبلا': 309,
#  'بود..': 9,
#  'سری': 183,
#  'چروک': 28,
#  'لورده': 1,
#  'انگار': 210,
#  ...}

# %%
positive_class_count = token_counter(lable_one.comment) # To-Do
positive_class_count
# Out:
# {'قیمت': 7468,
#  'وکیفیت': 26,
#  'پیشنهادمیکنم': 9,
#  'حتما': 762,
#  'خرید': 2414,
#  '': 4509,
#  'حدود۴۰': 1,
#  'تومن': 871,
#  'کالا': 1708,
#  'میکنه': 553,
#  '.': 1259,
#  'خریدم': 2442,
#  'چندروز': 4,
#  'قیمتش': 4785,
#  'کرد.': 56,
#  'رنگش': 299,
#  'خوشرنگ': 44,
#  'هست': 2248,
#  'بخصوص': 24,
#  'شماره': 31,
#  'پوستهایی': 1,
#  'گندمی': 2,
#  'خوان': 40,
#  'روشن': 133,
#  'تر': 921,
#  'بشه': 297,
#  'عکس': 487,
#  'میبینید': 21,
#  'نیست\r\nسوکت': 1,
#  'ها': 1141,
#  'جنس': 1349,
#  'پلاستیک': 188,
#  'رنگ': 975,
#  'آمیزی': 5,
#  'ضعیف': 137,
#  '\r\nیه': 8,
#  'سوکتشم': 1,
#  'ک': 572,
#  'اصلا': 1220,
#  'کج': 35,
#  'هست\r\nرو': 1,
#  'بدنه': 92,
#  'سیم': 107,
#  'نوشته': 141,
#  'ساخت': 202,
#  'چین': 29,
#  'مدل': 495,
#  'دیگه': 941,
#  'کابل': 113,
#  '۶۰': 33,
#  'اینا،': 1,
#  '۱۰۰': 50,
#  'اینا': 75,
#  'زده': 177,
#  'گفتم': 78,
#  'اصلی': 162,
#  'باشه': 824,
#  'اینطور': 25,
#  'استفاده': 1693,
#  'کیفیت': 3101,
#  'داره': 3799,
#  'تاچ': 19,
#  'میشه': 1357,
#  'مجبور': 71,
#  'میشی': 9,
#  'بکنی.': 1,
#  'پرایویسی': 1,
#  'واقعا': 1827,
#  'کار': 1085,
#  'میکنه.': 76,
#  'حیف': 120,
#  'چسبش': 31,
#  'خراب': 205,
#  'پولمو': 20,
#  'ریختم': 28,
#  'نمونه\u200cهای': 4,
#  'مشابه': 165,
#  'بازار': 686,
#  'ارزونتر': 165,
#  'هستش.': 35,
#  '\r\nکیفیتش': 7,
#  'فرقی': 60,
#  'نداره': 1073,
#  'جاهای': 42,
#  'خوبه': 3503,
#  'خوشگل': 118,
#  'خوش': 469,
#  'دوخت': 165,
#  'جنسشم': 68,
#  'نمونه': 89,
#  'اصل': 145,
#  'کاربردی': 211,
#  'مقرون': 141,
#  'بصرفه': 120,
#  'است...': 5,
#  'سلام': 414,
#  'دوستان': 329,
#  'عالیه': 1445,
#  '.دیگه': 2,
#  'خاکستر': 2,
#  'نمیبینید.قیمت': 1,
#  'مناسبی': 478,
#  'داره.': 353,
#  'تازه': 251,
#  'هستم': 419,
#  'واسه': 397,
#  'اشتباه': 110,
#  'بگردید': 4,
#  'تاییش': 3,
#  'نصف': 135,
#  'مرتکب': 1,
#  'نشین.ممنون': 1,
#  'دی': 210,
#  'جی': 145,
#  'شگفت': 1212,
#  'انگیز': 1149,
#  'خریدم،': 77,
#  'نمی': 527,
#  'ارزد.': 11,
#  '\r\nمشکل': 1,
#  'اصلیش': 30,
#  'اینه': 184,
#  'سایزش': 175,
#  'درست': 259,
#  'خاطر': 125,
#  'باریک': 16,
#  'نوک': 31,
#  'کفشه.\r\nرویشم': 1,
#  'سریع': 125,
#  'خط': 128,
#  'افتاد': 40,
#  'شیشه': 82,
#  'جلو': 29,
#  'دنا': 2,
#  'گرفتم': 883,
#  'شیک': 238,
#  'شد،': 15,
#  'بگیرید': 167,
#  'پشیمون': 171,
#  'نمیشید،': 3,
#  'راحته.': 9,
#  'قبلا': 208,
#  'ازاین': 22,
#  'راحت': 370,
#  'ادم': 37,
#  'احساس': 56,
#  'راحتی': 121,
#  'میکنه.سایز': 1,
#  'بندیش': 70,
#  'مشکل': 186,
#  'سایزم': 13,
#  '75هستش': 1,
#  '80': 24,
#  'سفارش': 799,
#  'دادم': 588,
#  'بازم': 156,
#  'برام': 211,
#  'کوچیک': 240,
#  'ناراحت': 8,
#  'شدم.': 16,
#  'الان': 541,
#  'ی': 437,
#  'ماهه': 59,
#  'میکنم': 1487,
#  'ارزش': 1713,
#  'نداره.': 94,
#  'قطرش': 5,
#  'دقت': 184,
#  'نکرده': 43,
#  'بودم': 687,
#  'سرش': 28,
#  'یکم': 566,
#  'بود.': 451,
#  'چوب': 55,
#  'اشم': 3,
#  'سوراخ': 41,
#  'کلا': 263,
#  'ارزید': 50,
#  'اون': 462,
#  'توضیح': 17,
#  'اورژینال': 2,
#  'فضایی': 12,
#  'کپیش': 4,
#  'توقع': 120,
#  'نداشته': 147,
#  'باشید': 165,
#  'راضی': 1421,
#  'پیشنهادم': 7,
#  'آقایون': 3,
#  'عید': 8,
#  'گرون': 502,
#  'ارزد': 38,
#  '\nبا': 30,
#  'تشکر': 156,
#  'انتظار': 341,
#  'ماندگاری': 103,
#  'عطر': 106,
#  'های': 1468,
#  'خنک': 35,
#  'استثنایی': 4,
#  'مصرف': 165,
#  'نگه': 116,
#  'میداره': 39,
#  '،': 1300,
#  'دوست': 242,
#  'دارم.': 25,
#  'فصل': 15,
#  'دیجی': 1626,
#  'هستش': 404,
#  'مغازه': 161,
#  'خریداری': 262,
#  'دیدمش': 13,
#  'قیمتشم': 309,
#  'ارزون': 360,
#  'سرخ': 10,
#  'کن': 68,
#  'خوبیه': 534,
#  'راضیم': 511,
#  'روغن': 84,
#  'چیزو': 1,
#  'میده': 301,
#  'اینو': 238,
#  'تقریبا': 198,
#  'میلیون': 85,
#  'ماست': 22,
#  'یونانی': 2,
#  'امتحان': 100,
#  'گردم': 5,
#  'بهتره': 334,
#  'روز': 342,
#  'گرونتر': 119,
#  'توروخدا': 1,
#  'نکنید': 204,
#  'بسه': 2,
#  'نکردم': 209,
#  'خوبه\r\nامروز': 1,
#  'گلریز': 3,
#  'پایینی': 44,
#  'نداشتم': 120,
#  'دستگاه': 201,
#  'شبکه': 8,
#  'عوض': 108,
#  'میکنید': 90,
#  'اسلوموشن': 1,
#  'نمیشه': 360,
#  'نخرید': 258,
#  'ضرر': 61,
#  'کردید': 16,
#  'قشنگ': 212,
#  'پولتونو': 40,
#  'بریزید': 30,
#  'اشغال': 22,
#  'ال': 25,
#  'ای': 816,
#  'دیش': 1,
#  'برید۵۰': 1,
#  'دلاریشم': 1,
#  'بخرید': 909,
#  'دکوره': 1,
#  'تیونر': 1,
#  'امریکایی': 5,
#  'تایید': 19,
#  'حدودا': 41,
#  'نیم': 75,
#  'کیلو': 23,
#  'خطای': 4,
#  'اندازه': 637,
#  'قطعا': 60,
#  'ترازو': 12,
#  'میخرن': 5,
#  'وزنشون': 1,
#  'براشون': 11,
#  'مهمه': 28,
#  'رفتن': 27,
#  'دنبال': 106,
#  'خریدن': 91,
#  'خطا': 7,
#  'چشم': 102,
#  'پوشی': 10,
#  'نیست...من': 1,
#  'مرجوعش': 58,
#  'کردم..به': 1,
#  'نظرم': 559,
#  'ناز': 13,
#  'گوگولیه': 4,
#  'واقعن': 17,
#  'پیشنهاد': 1169,
#  'چاپ': 98,
#  'کیفیت،': 18,
#  'اجزا': 1,
#  'جدا': 107,
#  'بود،': 148,
#  'جمله': 16,
#  'خوبه.\nکلا': 1,
#  'پیکسل': 14,
#  'هزار': 360,
#  'تومنی': 76,
#  'هستن.': 15,
#  '۵': 96,
#  'بهترن': 3,
#  'پلاستیکی': 87,
#  'نامرغوب': 14,
#  'است.': 218,
#  'باتوجه': 149,
#  'بيشتري': 2,
#  'ممنون': 393,
#  'موجودی': 8,
#  '\r\nقیمت': 35,
#  'صعودی': 1,
#  'شیبی': 1,
#  '65000': 1,
#  'ابتدای': 2,
#  'سال': 301,
#  'بسنه': 1,
#  '34': 6,
#  'تایی': 25,
#  'رقم': 4,
#  'رسیده،': 2,
#  '\nاندازش': 4,
#  'کوچیکه': 191,
#  '\nبرای': 15,
#  'بازی': 299,
#  'فکری': 11,
#  'هام': 25,
#  'اونا': 25,
#  'دیجیکالا': 209,
#  'یه': 1718,
#  'وقت': 125,
#  'تاس': 5,
#  'باشن': 24,
#  'قیمتی': 355,
#  'داخل': 267,
#  'ام\r\nکیفیت': 1,
#  'ساختش': 40,
#  'خوبه\r\nعکس': 1,
#  'جعبه': 206,
#  '42': 6,
#  'پارچه': 149,
#  'گذاشته': 58,
#  '32': 7,
#  'راستش': 21,
#  'فکرکنم.': 1,
#  'تعریفشو': 5,
#  'دستم': 422,
#  'خورد': 86,
#  'ذوقم': 28,
#  'یادم': 5,
#  'اومد': 193,
#  'بابتش': 13,
#  'چقدر': 50,
#  'نیشم': 1,
#  'بازشد': 1,
#  'درکل': 160,
#  'ارزششو': 46,
#  'باششی': 1,
#  'بوى': 3,
#  'خوبي': 33,
#  'قيمت': 93,
#  'نسبتا': 161,
#  'توى': 1,
#  'تخفيف': 30,
#  'ويژه': 7,
#  'موندگاريشم': 1,
#  'بد': 606,
#  'نيست': 14,
#  'حرف': 121,
#  'ممنونم': 129,
#  'تامین': 10,
#  'مرسی': 54,
#  'کالا.این': 1,
#  'هندزفری': 89,
#  'تناسب': 13,
#  'سالم': 138,
#  'مشکلی': 241,
#  'نداشت': 292,
#  'شارژ': 272,
#  'جوابدهیش': 1,
#  'خوبه.': 273,
#  'توجه': 1134,
#  'قیمت،': 46,
#  'بالایی': 265,
#  'پشتی': 14,
#  'کوتاه': 66,
#  'عرض': 44,
#  'نشیمنگاه': 1,
#  'زن': 13,
#  'جوریه': 12,
#  'باطریشم': 1,
#  'میداره.': 6,
#  'قدرت': 101,
#  'موتور': 53,
#  'عالیه.': 127,
#  'ب': 479,
#  'تره.': 18,
#  'داره.فقط': 3,
#  'خورده': 203,
#  'بدنش': 24,
#  'لیزه': 1,
#  'دست': 417,
#  'سر': 178,
#  'میخورع': 1,
#  'محصول': 811,
#  'درصد': 132,
#  'الکل': 29,
#  'توصیه': 604,
#  'بخرید.': 83,
#  'شکل': 63,
#  'ظاهری': 42,
#  'توی': 789,
#  'گوش': 125,
#  'میگیره': 64,
#  'زیباست': 122,
#  'قصد': 44,
#  'خریدش': 418,
#  'دارین': 38,
#  'زمانی': 50,
#  'اف': 48,
#  'بگیرین': 56,
#  '۲دقیقه': 2,
#  'میکنه.صدای': 1,
#  'کم.درکل': 1,
#  'خوبه.یسری': 1,
#  'نظرها': 7,
#  'نمیدونم': 158,
#  'چیه': 17,
#  'نوشتن': 44,
#  'بیست': 33,
#  'دقیقه': 66,
#  'بلد': 19,
#  'نیستن': 24,
#  'کاکردشو.خوبه': 1,
#  'قیمتش.بیرون': 1,
#  'گرونتره.ممنون': 1,
#  'کالا.': 35,
#  'دوتا': 166,
#  'یلدا': 14,
#  'تن': 70,
#  'مقدار': 190,
#  'گوشت': 33,
#  'ماهی': 53,
#  'یکیش': 54,
#  'چرخ': 21,
#  'روان': 64,
#  'وزن': 73,
#  'متناسب': 46,
#  'ریز': 78,
#  'یکمم': 6,
#  'رطوبت': 17,
#  'متغیر': 1,
#  'نشون': 61,
#  'میده.': 37,
#  'فردایروزی': 1,
#  'کاهش': 37,
#  'تیوپ': 9,
#  'پاره': 107,
#  'کیفیت،زیبایی': 1,
#  'کارایی': 208,
#  'ارزنده': 19,
#  'داشتم': 307,
#  'جنسش': 754,
#  'معمولی': 307,
#  'نرمه.': 2,
#  '۴۷': 5,
#  'خریده': 109,
#  'بودم.': 52,
#  'دوستشون': 4,
#  '.نازک': 1,
#  'هفته': 152,
#  'ست': 124,
#  'رگال': 2,
#  'راضبم': 2,
#  'خداروشکر': 22,
#  'شرکت': 82,
#  'سازنده': 20,
#  'متشکر': 2,
#  'بخاطر': 185,
#  'تخفیف': 1380,
#  'کتاب': 490,
#  'میزنه،': 3,
#  'جوران': 1,
#  'ساقربلند\r\nجنسش': 1,
#  'عالیییی': 11,
#  'بود\r\nخیلی': 4,
#  'راضیم.': 49,
#  'نخیه': 4,
#  'سبک': 131,
#  'اصلاااا': 6,
#  'نمیده.': 8,
#  'گوشی': 777,
#  'حرفه': 67,
#  'برا': 315,
#  'گیم': 38,
#  'نمیکنن': 10,
#  'داره\r\nبهرحال': 1,
#  'سایت': 122,
#  'خوبتون': 5,
#  'محصولی': 27,
#  'دیدم': 241,
#  'دوبرابر': 23,
#  'نیودم': 1,
#  'لذت': 57,
#  'بردم': 20,
#  'ارزه،': 17,
#  'پول': 393,
#  'بدید': 67,
#  'همون': 306,
#  'قدر': 29,
#  'خورید.': 1,
#  'خریدهایی': 5,
#  'کردم،': 51,
#  'سری': 135,
#  'محصولات': 247,
#  'موادی': 2,
#  'نشانگر': 3,
#  'مواد': 62,
#  'اولیه\u200cی': 1,
#  'صورتی': 84,
#  'خطرزاست': 1,
#  'استفاده\u200cی': 1,
#  'باشید.': 20,
#  'منی': 8,
#  'ندارم': 60,
#  'مناسبه.': 106,
#  'ظاهر': 144,
#  'زیبایی': 157,
#  'دارن.': 11,
#  'بازاره': 18,
#  'کتابی': 29,
#  'یکبار': 68,
#  'خوندن': 54,
#  'داره\r\nبخرید': 1,
#  'عالی\r\nهزینه': 1,
#  'سرمایه': 28,
#  'گزاری': 27,
#  'است\r\nو': 9,
#  'خودمون': 20,
#  'ضایعات': 3,
#  'ام': 353,
#  'هایگلاس': 1,
#  'رنگهای': 28,
#  'مختلف': 77,
#  'لب': 43,
#  'پریده': 9,
#  'تیز': 51,
#  'چتد': 1,
#  'بابام': 4,
#  '\nخیلی': 12,
#  'بابام\u200cچشمش': 1,
#  'ضعیفه': 101,
#  'نمیتونه': 10,
#  'بخونه': 4,
#  'حروف': 4,
#  '\nقیمت': 16,
#  'مدتی': 52,
#  'پایه': 111,
#  'وازخریدم': 2,
#  'عکاسی': 10,
#  'وفیلمبرداری': 1,
#  'عالیه.قیمتش': 2,
#  'برند': 377,
#  'مارک': 185,
#  'وبرندشان': 1,
#  'میگیرن': 11,
#  'خوبه...': 8,
#  'کفش': 219,
#  'پسرم': 65,
#  'خریدم\r\nخودش': 1,
#  'طرح': 185,
#  'راضیه\r\nبنظر': 1,
#  'خودم': 242,
#  'بدی': 176,
#  'پوست': 212,
#  'مختلط': 3,
#  'دارم': 373,
#  'نرم': 275,
#  'خشک': 178,
#  'خریدنش': 20,
#  'خمیر': 26,
#  'دندان': 21,
#  'وقته': 32,
#  'میزنم': 21,
#  'گردن': 22,
#  'بقیه': 240,
#  'بالاتره': 36,
#  'العاده': 293,
#  'تأسفه': 1,
#  'داشتنی': 13,
#  '\r\nجنس': 11,
#  'مناسبه': 678,
#  'میکردم': 160,
#  'جستجو': 5,
#  '\r\nممنون': 28,
#  'کد': 48,
#  'برنج': 38,
#  'میخرم': 103,
#  'گلستان': 13,
#  'برنجش': 1,
#  'جالب': 128,
#  'انداز': 62,
#  'نسب': 30,
#  'قیمشم': 1,
#  'قیمتهای': 41,
#  '۷۴هزار': 1,
#  'بتونم': 16,
#  'بدم': 101,
#  'برچسب': 43,
#  'سازمان': 2,
#  'بهداشت': 3,
#  '۲۸': 9,
#  'فوریه': 1,
#  '۲۰۲۱': 2,
#  'انقضا': 19,
#  'مدتش': 1,
#  'کمه': 124,
#  '.برای': 10,
#  'پایین': 454,
#  'فروختن.': 2,
#  'موهام': 24,
#  'شامپویی': 4,
#  'بهش': 131,
#  'نساخت': 2,
#  'شوک': 2,
#  'شوره': 9,
#  'ریخت': 11,
#  'شامپو': 65,
#  'نظرات': 162,
#  '\r\nجنسش': 7,
#  'باکیفیت': 90,
#  '\r\n': 38,
#  'گرونه': 298,
#  '،مغازه': 1,
#  'میدن': 76,
#  'ازاینم': 1,
#  'جنسشون': 19,
#  'بودم،': 29,
#  'بهترینه': 28,
#  'نمیشید': 47,
#  'کیفیتش': 593,
#  'دوربین': 127,
#  'مشاغل': 5,
#  'خاصه': 7,
#  'بخرین': 190,
#  'جنش': 3,
#  'محکمی': 51,
#  'مرتب': 45,
#  'ریش': 28,
#  'صداش': 113,
#  'نیست.': 167,
#  'ارزندست': 2,
#  'هدیه': 170,
#  'گرفتم\nاز': 1,
#  'بانمکه\nکیفیت': 1,
#  'داره\nموزیک': 1,
#  'داره\nارزش': 3,
#  '۳۰': 65,
#  'تومان': 271,
#  'اختلاف': 47,
#  'صرفه': 538,
#  'بود.کیفیت': 1,
#  'است.ممنون': 1,
#  'خوبه..برگه': 1,
#  'هاش': 240,
#  'خوبن': 41,
#  'جلدش': 28,
#  'نازکه': 112,
#  'پالتوی': 2,
#  'گرم': 108,
#  'نیست،': 63,
#  'مطمئن': 50,
#  'نیستم': 81,
#  'بیارزه.': 3,
#  'سایزبندیش': 4,
#  'بزرگتر': 154,
#  'معمول': 9,
#  'هست.': 256,
#  'زیبا': 399,
#  'گوگولی': 10,
#  'خوشگلن\r\nجنس': 1,
#  'همونه': 20,
#  'میخواستم.': 5,
#  'دلیل': 77,
#  'سبکی': 17,
#  'زیره': 16,
#  'رنج': 219,
#  'شدت': 105,
#  'پیاده': 14,
#  'خب': 256,
#  'انتظاری': 20,
#  'پایی': 2,
#  'خارجی': 120,
#  'رده': 66,
#  'پاش': 11,
#  'عکسیه': 1,
#  'گذاشتن': 50,
#  'رویه': 18,
#  'عادی': 41,
#  'مال': 46,
#  'بپوشین': 3,
#  'برید': 31,
#  'اگه': 742,
#  'خواستید': 13,
#  'دونه': 118,
#  'بند': 111,
#  'بنداش': 6,
#  'آهنرباش': 4,
#  'پولتون': 59,
#  'میریزید': 4,
#  'سطل': 21,
#  'آشغال': 31,
#  'ظاهراً': 2,
#  'ایرانی': 137,
#  'ست.': 10,
#  'کلاه': 39,
#  'خوبیه..هم': 1,
#  'گرم.فقط': 1,
#  'پسر': 23,
#  'هشت': 24,
#  'من،امسال': 1,
#  'میشه.': 112,
#  'ببینید،': 1,
#  'قبولی': 104,
#  '670': 1,
#  'براش': 121,
#  'انصافاً': 5,
#  'زیاده،': 8,
#  '150': 16,
#  '200': 22,
#  'بیشتر.': 6,
#  'شگفتانه': 7,
#  'ارزشش': 68,
#  'وگرنه': 83,
#  'گرونه،ولی': 2,
#  'حس': 89,
#  'صورت': 156,
#  'چسب': 158,
#  'خالی': 58,
#  'بود\r\n۲مداد': 1,
#  'ویک': 2,
#  'پاک': 147,
#  'وتراش': 1,
#  '\r\nنمی': 1,
#  'ارزد\r\nجلد': 1,
#  'بچه': 286,
#  'مرجوع': 298,
#  'میکرپم': 1,
#  'آرمیچر': 3,
#  'ارسال': 290,
#  'رایگان': 19,
#  'بسته': 753,
#  'بزرگه': 96,
#  'قوطی': 23,
#  'داخلشو': 2,
#  'تحویل': 165,
#  'میگیرم': 32,
#  'اینطوری': 15,
#  'استرس': 7,
#  'دهنده': 32,
#  'قیافش': 6,
#  'نامیزان': 2,
#  'ترسیدم.': 1,
#  'خواهرم': 49,
#  'عاشقش': 28,
#  'قشنگه': 202,
#  'بانمکه': 2,
#  'رنگشم': 22,
#  'ملیحه': 1,
#  'خوشتون': 13,
#  'میاد': 185,
#  'چرم': 70,
#  'مطابق': 65,
#  'تصویر،': 1,
#  'خریدش\u200c': 1,
#  'رو.': 13,
#  'دوامی': 4,
#  'گرفتم.': 50,
#  'باصرفه': 17,
#  'شیرینه.': 1,
#  'مهمتر': 23,
#  'مشتریان': 4,
#  'قائله': 1,
#  'هزینه': 316,
#  'متحمل': 3,
#  'کاغذ': 106,
#  'کاهی': 31,
#  'شده،از': 1,
#  'قدیم': 29,
#  'گفتن': 61,
#  'ارزانی': 5,
#  'سنجاق': 2,
#  'است.\r\nکیفیت': 1,
#  'وقیمت': 42,
#  'هردوتامهم': 1,
#  'هستند.': 16,
#  'انبردست': 7,
#  'فعلا': 75,
#  'خاصی': 121,
#  'ازش': 552,
#  'ظاهرا': 23,
#  'بنظرم': 274,
#  'پولی': 178,
#  'میدید': 56,
#  'باشه.': 85,
#  'لبه': 67,
#  'صیقل': 1,
#  'نشده': 115,
#  'ببره.': 2,
#  'قطره': 13,
#  'گذاشتم': 79,
#  'تمیز': 198,
#  'شه.': 4,
#  'نورش': 50,
#  'ایده\u200cش': 1,
#  'جذابه.': 2,
#  'بهتره.': 27,
#  'میصرفه': 28,
#  'اندازشون': 5,
#  'نظرکیفیت': 2,
#  'پینشنهاد': 1,
#  'نصبش': 47,
#  'کلیه': 5,
#  'اجناسرا': 1,
#  'اختیار': 4,
#  'مردم': 38,
#  'قرار': 120,
#  'میدهند': 3,
#  'انتظارشو': 7,
#  'نکنه': 26,
#  'بیخود': 9,
#  'نریزید': 19,
#  'انقدر': 99,
#  'ارزونه': 71,
#  'دیر': 62,
#  'کافیینش': 1,
#  '4': 55,
#  'کنن': 75,
#  '\r\nاونوقت': 1,
#  'خوبیه.': 35,
#  'کیف': 242,
#  'دوشی': 5,
#  'فروش': 258,
#  'میارزه۳۶۰۰۰ت': 1,
#  'بسم': 3,
#  'الله': 5,
#  'الرحمن': 3,
#  'الرحیم\r\nبا': 1,
#  'وجودی': 1,
#  'برندهای': 77,
#  'ظرف': 67,
#  'نگهدارنده': 21,
#  '\r\nباید': 5,
#  'بگم': 216,
#  'مجموع': 57,
#  'دم': 96,
#  'دستی': 78,
#  'راانداز.\r\nتو': 1,
#  'فریزرم': 1,
#  'کنم.مشکلی': 1,
#  '.\r\nچند': 1,
#  'ماهیه': 2,
#  '.درهاشونم': 1,
#  'باهاشون': 10,
#  'ندارم\r\nتو': 1,
#  'ظرفشوییم': 1,
#  'می\u200cزارم.چیزیش': 1,
#  '.\r\nقیمتشم': 1,
#  'آفی': 2,
#  'ماله': 5,
#  '۳': 118,
#  'پیشه': 6,
#  'کمتر': 263,
#  '۶': 78,
#  'ماه': 237,
#  'نقض': 3,
#  'قوانین': 1,
#  'خوده': 14,
#  'بوی': 333,
#  'ناممطبوع': 1,
#  'اسپری': 53,
#  'پاشش': 9,
#  'خرابه': 12,
#  'نمیکنم': 157,
#  'توو': 22,
#  '۱': 50,
#  'میلیونی': 15,
#  'نمیاد': 55,
#  'فروشنده': 196,
#  'دارن': 198,
#  'آبروی': 1,
#  'میبرن': 5,
#  'زودپز': 2,
#  'تازگی': 15,
#  'راضیم.هم': 1,
#  'زود': 232,
#  'پز': 9,
#  'قشنگی': 83,
#  'پخت': 22,
#  'غذاهام': 1,
#  'اسون': 4,
#  'شده.ممنون': 1,
#  'بلزا': 1,
#  'کف': 63,
#  'تمیزی': 23,
#  'رایحه': 81,
#  '\r\nاما': 41,
#  'دونم': 14,
#  'هارو': 49,
#  'زنه': 8,
#  'الی': 21,
#  'مفته': 35,
#  'آرامش': 4,
#  'بااین': 77,
#  'تجربه': 33,
#  'نازک': 151,
#  'حریر': 3,
#  'همخوانی': 8,
#  'س\r\nلطفا': 1,
#  'توقعتون': 3,
#  '،البته': 8,
#  'آسترش': 3,
#  'نخ': 67,
#  'پنبه': 24,
#  'میرزه': 36,
#  'نهایت': 49,
#  'آستر': 10,
#  'خودتون': 77,
#  'ش': 145,
#  'بشه.': 34,
#  'بنده': 79,
#  'سرکان': 5,
#  'فیلترهای': 1,
#  'بالاست.': 63,
#  'ریمل': 26,
#  'همونطور': 11,
#  'بلند': 96,
#  'کنندس': 17,
#  'حجم': 185,
#  'دهندگی': 1,
#  'آنچنانی': 14,
#  'مژه\u200cهاتون': 1,
#  'پررنگ': 19,
#  'ومشکی': 1,
#  'میکنه.دوستان': 1,
#  'ریمل،ریمل': 1,
#  'ایه': 37,
#  'انگیز؛ولی': 1,
#  'خارج': 34,
#  'عنوان': 165,
#  'روزانه': 47,
#  'نمیصرفه': 25,
#  'همونقدری': 1,
#  '۳۰یا۲۰تومنی': 1,
#  'براتون': 121,
#  'داره.اگرهم': 1,
#  'هستید': 43,
#  'بذارید': 17,
#  'برندتر': 1,
#  'بهتری': 146,
#  'بگیرید،': 2,
#  'کنیدولذت': 1,
#  'ببرید.': 5,
#  'یادداشتها': 1,
#  'یادآورها': 1,
#  'مناسبه\r\nقیمتش': 1,
#  'مادرم': 32,
#  'موهاش': 14,
#  'میسازه': 2,
#  'میره': 82,
#  'صدای': 161,
#  'کیس': 45,
#  'هنسفری': 3,
#  'ندارن': 44,
#  'قبوله': 87,
#  'اصالت': 12,
#  'بارکد': 3,
#  'واشر': 5,
#  'تقلبی': 20,
#  'زیاده': 181,
#  'تشخیصی': 1,
#  'همینه': 24,
#  'کثیف': 40,
#  'کاری': 75,
#  '\r\nبا': 40,
#  'دوبار': 30,
#  'لاک': 27,
#  '\r\nقیمتش': 25,
#  'روزه': 53,
#  'رسیده': 61,
#  'لپ': 41,
#  'تاپ': 46,
#  'z510': 1,
#  'لنوو': 8,
#  'سرعت': 107,
#  'شک': 242,
#  'نکنید،': 4,
#  'گارانتی': 87,
#  'اطمینان': 18,
#  'زاویه': 8,
#  'دماغ': 3,
#  'اذیت': 97,
#  'کنه': 222,
#  ...}

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# وقت آن رسیده که به طراحی بخش اصلی الگوریتم یعنی محاسبه‌ی احتمال یک کلاس به شرط یک متن بپردازیم تا آن کلاسی که بیشترین احتمال را کسب کرده به عنوان پیش‌بینی خروجی داده شود. جهت محاسبه‌ی احتمال یک کلاس به شرط مشاهده‌ی یک متن (لیستی از توکن‌ها) طبق ایده‌ی الگوریتم بیز ساده‌لوحانه کافیست احتمال رخداد هرکدام از اجزای آن (در اینجا توکن‌ها) را به شرط آن کلاس محاسبه کرده و در همدیگر ضرب کنیم. حاصل را نیز در نهایت در احتمال آن کلاس ضرب خواهیم کرد. یعنی خواهیم داشت:
# </font>
# </p>

# %% [markdown]
# $P(class|t_1, t_2, ..., t_n)=P(t_1, t_2, ..., t_n|class)\times P(class)=P(t_1|class)\times P(t_2|class)\times ...\times P(t_n|class)\times P(class)$

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# و اما برای محاسبه‌ی احتمال رخداد هر توکن به شرط یک کلاس می‌توانیم تعداد رخداد توکن در میان متن‌های آن کلاس را بر مجموع رخداد توکن‌های متون مربوط به آن کلاس تقسیم کنیم. تعداد رخداد هر توکن در هر کلاس در دیکشنری‌های <code>positive_class_count</code> و <code>negative_class_count</code> ذخیره شده است. مجموع رخداد توکن‌های یک کلاس را نیز می‌توانید با جمع تمام مقادیر موجود در دیکشنری آن کلاس به‌دست آورید. اگر بخواهیم مفهوم این قسمت را به شکل فرمول نمایش دهیم خواهیم داشت:
# </font>
# </p>

# %% [markdown]
# $\large P(w_i|class)=\frac{count(t_i, class)}{\sum_{t \in V}{count(t, class)}}$

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# با این حال فرمول بالا چندان عملکرد خوبی نخواهد داشت. فرض کنید یک متن آزمون دارید و می‌خواهید احتمال هر توکن آن در یک کلاس را محاسبه کنید اما آن توکن تاکنون دیده نشده و تعداد رخدادش صفر است. در اینصورت احتمال توکن به شرط کلاس معادل صفر شده و هنگامیکه این عدد در احتمال سایر توکن‌ها ضرب می‌شود حاصل را به کلی صفر می‌کند. جهت رفع این مشکل ایده‌ای با نام <i>add-1 smoothing</i> مطرح می‌شود که می‌گوید تعداد رخداد کلمه‌ای که تاکنون دیده‌نشده به‌جای صفر معادل یک در نظر گرفته شود. جهت اعمال این تغییر لازم است به تعداد تکرار تمام توکن‌ها نیز یک واحد اضافه کنیم و جهت آنکه نسبت‌ها به هم نخورد نیاز است تا در مخرج کسر نیز اندازه‌ی لغت‌نامه را قرار دهیم. منظور از لغت‌نامه که آن را در فرمول با <code>V</code> نشان می‌دهیم تمام توکن‌های یکتای موجود است. یعنی باید توکن‌های موجود در دیکشنری تمام کلاس‌ها را با هم ترکیب کنید و موارد یکتا را به دست آورید. با اعمال تغییراتی که شرح داده شد نهایتاً به فرمول زیر خواهیم رسید:
# </font>
# </p>

# %% [markdown]
# $\large P(w_i|class)=\frac{count(t_i, class) + 1}{(\sum_{t \in V}{count(t, class)}) + |V|}$

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال از شما می‌خواهیم که در تابع <code>compute_probability</code> یک متن و یک کلاس (<code>0</code> یا <code>1</code>) را گرفته و طبق فرمول‌های معرفی‌شده به محاسبه‌ی احتمال آن کلاس به شرط آن متن بپردازد. یعنی نیاز است احتمال هر توکن به شرط آن کلاس را محاسبه کرده، حاصل تمام آن‌ها را در هم ضرب کرده، نهایتاً در احتمال آن کلاس ضرب کنید و حاصل را برگردانید.
# </font>
# </p>

# %%
total_negative = sum(negative_class_count.values())
total_positive = sum(positive_class_count.values())
txt = 'از همه نظر عالی و یک خرید خوب در قیمت حدود۴۰تومن'

x = 1
def compute_probability(text, cls):
    re = token_counter(text)
    for key, val in re.items():
        y = val / total_negative
        x = x * y
    if cls == 0:
        
    result = x*cls
    return result  # To-Do 




compute_probability(txt, 0)
# Out:
# 1.1244006107911164e-99

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# اکنون تابع <code>predict</code> را به گونه‌ای تکمیل کنید که لیستی از متن‌ها را گرفته و یک آرایه‌ی نامپای تک‌بعدی از برچسب پیش‌بینی‌شده برای آن‌ها تولید کند. جهت پیش‌بینی برچسب یک متن کافیست متن ورودی را یک‌بار با کلاس <code>0</code> و یک‌بار با کلاس <code>1</code> به تابع <code>compute_proability</code> بدهید تا احتمال هر کلاس محاسبه شود. سپس آن کلاسی که مقدار احتمال بیشتری را تولید کرده است به عنوان برچسب پیش‌بینی‌شده انتخاب کنید.
# </font>
# </p>

# %%
input_text = train_data.head().comment.to_list()
x_train = train_data['comment']


def predict(test):
    predictions = []
    # To-Do
    for txt in test:
        com_p0 = compute_probability(txt, P0)
        com_p1 = compute_probability(txt, P1)
        if com_p1 > com_p0:
            predictions.append(1)
        else:
            predictions.append(0)
    return np.array(predictions)

predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 17
#      14             predictions.append(0)
#      15     return np.array(predictions)
# ---> 17 predict(x_train)
#
# Cell In[14], line 9, in predict(test)
#       7 # To-Do
#       8 for txt in test:
# ----> 9     com_p0 = compute_probability(txt, P0)
#      10     com_p1 = compute_probability(txt, P1)
#      11     if com_p1 > com_p0:
#
# Cell In[12], line 7, in compute_probability(text, cls)
#       5 def compute_probability(text, cls):
#       6     x = 1
# ----> 7     re = token_counter(text)
#       8     for key, val in re.items():
#       9         y = val / total_negative
#
# Cell In[6], line 7, in token_counter(texts)
#       5 for m in texts:
#       6     global ex
# ----> 7     ex = preprocessing(m)
#       8     for e in ex:
#       9         if e in count_dict.keys():
#
# Cell In[4], line 9, in preprocessing(text)
#       7 lst = text.split(' ')
#       8 for m in lst:
# ----> 9     if m not in stopwords_list():
#      10         filtered.append(m)
#      11 return filtered
#
# File ~/Desktop/Jump Machine Learning/qenv/lib/python3.9/site-packages/hazm/utils.py:28, in stopwords_list(stopwords_file)
#      26 def stopwords_list(stopwords_file=default_stopwords):
#      27 	with codecs.open(stopwords_file, encoding='utf8') as stopwords_file:
# ---> 28 		return list(map(lambda w: w.strip(), stopwords_file))
#
# File /usr/local/lib/python3.9/codecs.py:714, in StreamReaderWriter.__next__(self)
#     711 def __next__(self):
#     713     """ Return the next decoded line from the input stream."""
# --> 714     return next(self.reader)
#
# File /usr/local/lib/python3.9/codecs.py:645, in StreamReader.__next__(self)
#     642 def __next__(self):
#     644     """ Return the next decoded line from the input stream."""
# --> 645     line = self.readline()
#     646     if line:
#     647         return line
#
# File /usr/local/lib/python3.9/codecs.py:558, in StreamReader.readline(self, size, keepends)
#     556 # If size is given, we call read() only once
#     557 while True:
# --> 558     data = self.read(readsize, firstline=True)
#     559     if data:
#     560         # If we're at a "\r" read one extra character (which might
#     561         # be a "\n") to get a proper line ending. If the stream is
#     562         # temporarily exhausted we return the wrong line ending.
#     563         if (isinstance(data, str) and data.endswith("\r")) or \
#     564            (isinstance(data, bytes) and data.endswith(b"\r")):
#
# File /usr/local/lib/python3.9/codecs.py:498, in StreamReader.read(self, size, chars, firstline)
#     496     newdata = self.stream.read()
#     497 else:
# --> 498     newdata = self.stream.read(size)
#     499 # decode bytes (those remaining from the last call included)
#     500 data = self.bytebuffer + newdata
#
# KeyboardInterrupt:

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ارزیابی
# </font>
# </h3>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# ساخت مدل بیز ساده‌لوحانه به اتمام رسید و اکنون می‌توانید متن‌های خود را به مدل بدهید تا برچسب آن‌ها را پیش‌بینی کند. در این مرحله می‌توانید ابتدا داده‌های آموزشی را به تابع <code>predict</code> بدهید و پیش‌بینی‌های تولیدی را با برچسب‌های واقعی مقایسه کنید تا دقت مدل خود را بر روی داده‌های آموزشی بسنجید. این دقت می‌تواند تا حدی در اطمینان شما به پیاده‌سازیِ انجام‌گرفته کمک کند. جهت محاسبه‌ی دقت می‌توانید از تابع آماده‌ی <code>accuracy_score</code> استفاده کنید و در سیستم داوری نیز خروجی شما با این معیار سنجیده خواهد شد.
# </font>
# </p>

# %%
train_predictions = predict(x_train.to_list()) # To-Do

# %%
accuracy_score(train_data['price_value'], train_predictions) # To-Do
# Out:
# 0.520025

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>80</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %%
x_test = predict(test_data.comment.to_list())

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون نیاز است متون مربوط به مجموعه‌ی آزمون را به تابع <code>predict</code> بدهید تا مدل شما به پیش‌بینی برچسب برای آن‌ها بپردازد. در نهایت نتایج به‌دست‌آمده را در قالب جدول زیر آماده کنید و در دیتافریم <code>submission</code> ذخیره کنید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>price_value</code>|برچسب پیش‌بینی‌شده|
#
# </font>
# </div>
# </center>

# %%
submission = pd.DataFrame(x_test) # To-Do
submission.rename(columns={0: 'price_value'}, inplace=True)
submission
# Out:
#       price_value
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 7995            0
# 7996            0
# 7997            0
# 7998            0
# 7999            0
#
# [8000 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['comment_mining.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['comment_mining.ipynb', 'submission.csv']
